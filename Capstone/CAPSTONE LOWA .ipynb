# %%
import numpy as np
import pandas as pd 
import seaborn as sns 
import matplotlib.pyplot as plt
from warnings import filterwarnings
filterwarnings('ignore')

# %%
df1= pd.read_csv('Iowa Liquor Sales (Jan 2021-Jan 2022).csv')

# %%
df1
# Out:
#         invoice_and_item_number        date  store_number  \
# 0               INV-33179700135  04-01-2021          2576
# 1               INV-33196200106  04-01-2021          2649
# 2               INV-33184300011  04-01-2021          2539
# 3               INV-33184100015  04-01-2021          4024
# 4               INV-33174200025  04-01-2021          5385
# ...                         ...         ...           ...
# 1048570         INV-39816800042  03-09-2021          5868
# 1048571         INV-39790400013  03-09-2021          5145
# 1048572         INV-39806400009  03-09-2021          4585
# 1048573         INV-39782700007  03-09-2021          4795
# 1048574         INV-39809100004  03-09-2021          5512
#
#                                       store_name            address  \
# 0           Hy-Vee Wine and Spirits / Storm Lake     1250 N Lake St
# 1                            Hy-Vee #3 / Dubuque      400 Locust St
# 2                 Hy-Vee Food Store / Iowa Falls         640 S. Oak
# 3                     Wal-Mart 1546 / Iowa Falls          840 S Oak
# 4                             Vine Food & Liquor      2704 Vine St.
# ...                                          ...                ...
# 1048570             Brothers Market / Bloomfield    207 E Locust St
# 1048571                     South Side Food Mart  1101 Army Post Rd
# 1048572     Casey's General Store #2561 / Farley     306, 1st St SW
# 1048573            Walgreens #00359 / Des Moines  2545 E Euclid Ave
# 1048574  Casey's General Store #3639 / Postville    620 W Tilden St
#
#                     city  zip_code                         store_location  \
# 0             Storm Lake   50588.0   POINT (-95.200758 42.65318400000001)
# 1                Dubuque   52001.0   POINT (-90.666497 42.49721900000001)
# 2             Iowa Falls   50126.0           POINT (-93.262364 42.508752)
# 3             Iowa Falls   50126.0           POINT (-93.262446 42.503407)
# 4        West Des Moines   50265.0           POINT (-93.741511 41.580206)
# ...                  ...       ...                                    ...
# 1048570       Bloomfield   52537.0           POINT (-92.412847 40.752691)
# 1048571       Des Moines   50315.0           POINT (-93.628783 41.526511)
# 1048572           Farley   52046.0           POINT (-91.006139 42.439552)
# 1048573       Des Moines   50317.0  POINT (-93.568668 41.627702000000006)
# 1048574        Postville   52162.0           POINT (-91.580193 43.084432)
#
#          county_number      county  ...  item_number  \
# 0                 11.0  BUENA VIST  ...        64870
# 1                 31.0     DUBUQUE  ...        65200
# 2                 42.0      HARDIN  ...        38008
# 3                 42.0      HARDIN  ...        36648
# 4                 77.0        POLK  ...         4626
# ...                ...         ...  ...          ...
# 1048570           26.0       DAVIS  ...        52316
# 1048571           77.0        POLK  ...        11788
# 1048572           31.0     DUBUQUE  ...        26826
# 1048573           77.0        POLK  ...        64866
# 1048574            3.0   ALLAMAKEE  ...        11788
#
#                         item_description  pack bottle_volume_ml  \
# 0              Fireball Cinnamon Whiskey    48              100
# 1                   Tequila Rose Liqueur    12              750
# 2                     Smirnoff 80prf PET     6             1750
# 3                          Caliber Vodka    12              750
# 4                   Buchanan Deluxe 12YR    12              750
# ...                                  ...   ...              ...
# 1048570            Christian Bros Brandy    12              750
# 1048571                     Black Velvet     6             1750
# 1048572  Jack Daniels Old #7 Black Label    12              750
# 1048573        Fireball Cinnamon Whiskey    12              750
# 1048574                     Black Velvet     6             1750
#
#          state_bottle_cost state_bottle_retail  bottles_sold  sale_dollars  \
# 0                     0.90                1.35            48         64.80
# 1                    11.50               17.25             4         69.00
# 2                    14.75               22.13             6        132.78
# 3                     3.31                4.97            12         59.64
# 4                    20.99               31.49             2         62.98
# ...                    ...                 ...           ...           ...
# 1048570               6.00                9.00             3         27.00
# 1048571              10.45               15.68             6         94.08
# 1048572              15.57               23.36            12        280.32
# 1048573               9.00               13.50            12        162.00
# 1048574              10.45               15.68            12        188.16
#
#          volume_sold_liters  volume_sold_gallons
# 0                      4.80                 1.26
# 1                      3.00                 0.79
# 2                     10.50                 2.77
# 3                      9.00                 2.37
# 4                      1.50                 0.39
# ...                     ...                  ...
# 1048570                2.25                 0.59
# 1048571               10.50                 2.77
# 1048572                9.00                 2.37
# 1048573                9.00                 2.37
# 1048574               21.00                 5.54
#
# [1048575 rows x 24 columns]

# %%
df1.columns
# Out:
# Index(['invoice_and_item_number', 'date', 'store_number', 'store_name',
#        'address', 'city', 'zip_code', 'store_location', 'county_number',
#        'county', 'category', 'category_name', 'vendor_number', 'vendor_name',
#        'item_number', 'item_description', 'pack', 'bottle_volume_ml',
#        'state_bottle_cost', 'state_bottle_retail', 'bottles_sold',
#        'sale_dollars', 'volume_sold_liters', 'volume_sold_gallons'],
#       dtype='object')

# %%
df1.nunique()
# Out:
# invoice_and_item_number    1048575
# date                           118
# store_number                  1927
# store_name                    1921
# address                       1908
# city                           441
# zip_code                       478
# store_location                2413
# county_number                   99
# county                         119
# category                        56
# category_name                   56
# vendor_number                  188
# vendor_name                    192
# item_number                   3862
# item_description              3349
# pack                            20
# bottle_volume_ml                24
# state_bottle_cost             1165
# state_bottle_retail           1170
# bottles_sold                   268
# sale_dollars                  8423
# volume_sold_liters             528
# volume_sold_gallons            519
# dtype: int64

# %%
df1.describe().round(2)
# Out:
#        store_number    zip_code  county_number    category  vendor_number  \
# count    1048575.00  1048511.00     1048511.00  1048575.00     1048572.00
# mean        4111.39    51246.96          57.34  1053592.64         282.90
# std         1252.17      990.92          27.32    96819.24         142.83
# min         2106.00    50002.00           1.00  1011100.00          33.00
# 25%         2643.00    50314.00          31.00  1012100.00         205.00
# 50%         4162.00    51041.00          63.00  1031200.00         260.00
# 75%         5210.00    52302.00          77.00  1062500.00         395.00
# max         9049.00    57222.00          99.00  1901200.00         978.00
#
#        item_number        pack  bottle_volume_ml  state_bottle_cost  \
# count   1048575.00  1048575.00        1048575.00         1048575.00
# mean      54608.03       11.99            824.86              11.27
# std       92623.32        7.88            522.94              11.30
# min         258.00        1.00             20.00               0.89
# 25%       27102.00        6.00            375.00               6.00
# 50%       39918.00       12.00            750.00               8.98
# 75%       65200.00       12.00           1000.00              14.00
# max      999930.00       60.00           5250.00            1949.02
#
#        state_bottle_retail  bottles_sold  sale_dollars  volume_sold_liters  \
# count           1048575.00    1048575.00    1048575.00          1048575.00
# mean                 16.90         11.87        161.02                9.39
# std                  16.94         31.48        485.10               37.87
# min                   1.34          1.00          1.34                0.02
# 25%                   9.00          3.00         42.00                1.50
# 50%                  13.47          6.00         89.52                4.80
# 75%                  21.00         12.00        166.50               10.50
# max                2923.53       3780.00      56430.00             6615.00
#
#        volume_sold_gallons
# count           1048575.00
# mean                  2.47
# std                  10.01
# min                   0.00
# 25%                   0.39
# 50%                   1.26
# 75%                   2.77
# max                1747.49

# %%
df1.isna().sum()
# Out:
# invoice_and_item_number         0
# date                            0
# store_number                    0
# store_name                      0
# address                        64
# city                           64
# zip_code                       64
# store_location             117706
# county_number                  64
# county                         64
# category                        0
# category_name                   0
# vendor_number                   3
# vendor_name                     3
# item_number                     0
# item_description                0
# pack                            0
# bottle_volume_ml                0
# state_bottle_cost               0
# state_bottle_retail             0
# bottles_sold                    0
# sale_dollars                    0
# volume_sold_liters              0
# volume_sold_gallons             0
# dtype: int64

# %% [markdown]
# address,city,zip_code, store_location, country_number, country, vendor_number, vendor_name these column having duplicate values

# %%
df1.duplicated().sum()
# Out:
# 0

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1048575 entries, 0 to 1048574
# Data columns (total 24 columns):
#  #   Column                   Non-Null Count    Dtype
# ---  ------                   --------------    -----
#  0   invoice_and_item_number  1048575 non-null  object
#  1   date                     1048575 non-null  object
#  2   store_number             1048575 non-null  int64
#  3   store_name               1048575 non-null  object
#  4   address                  1048511 non-null  object
#  5   city                     1048511 non-null  object
#  6   zip_code                 1048511 non-null  float64
#  7   store_location           930869 non-null   object
#  8   county_number            1048511 non-null  float64
#  9   county                   1048511 non-null  object
#  10  category                 1048575 non-null  int64
#  11  category_name            1048575 non-null  object
#  12  vendor_number            1048572 non-null  float64
#  13  vendor_name              1048572 non-null  object
#  14  item_number              1048575 non-null  int64
#  15  item_description         1048575 non-null  object
#  16  pack                     1048575 non-null  int64
#  17  bottle_volume_ml         1048575 non-null  int64
#  18  state_bottle_cost        1048575 non-null  float64
#  19  state_bottle_retail      1048575 non-null  float64
#  20  bottles_sold             1048575 non-null  int64
#  21  sale_dollars             1048575 non-null  float64
#  22  volume_sold_liters       1048575 non-null  float64
#  23  volume_sold_gallons      1048575 non-null  float64
# dtypes: float64(8), int64(6), object(10)
# memory usage: 192.0+ MB

# %%
df1['date'] = pd.to_datetime(df1['date'])
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1048575 entries, 0 to 1048574
# Data columns (total 24 columns):
#  #   Column                   Non-Null Count    Dtype
# ---  ------                   --------------    -----
#  0   invoice_and_item_number  1048575 non-null  object
#  1   date                     1048575 non-null  datetime64[ns]
#  2   store_number             1048575 non-null  int64
#  3   store_name               1048575 non-null  object
#  4   address                  1048511 non-null  object
#  5   city                     1048511 non-null  object
#  6   zip_code                 1048511 non-null  float64
#  7   store_location           930869 non-null   object
#  8   county_number            1048511 non-null  float64
#  9   county                   1048511 non-null  object
#  10  category                 1048575 non-null  int64
#  11  category_name            1048575 non-null  object
#  12  vendor_number            1048572 non-null  float64
#  13  vendor_name              1048572 non-null  object
#  14  item_number              1048575 non-null  int64
#  15  item_description         1048575 non-null  object
#  16  pack                     1048575 non-null  int64
#  17  bottle_volume_ml         1048575 non-null  int64
#  18  state_bottle_cost        1048575 non-null  float64
#  19  state_bottle_retail      1048575 non-null  float64
#  20  bottles_sold             1048575 non-null  int64
#  21  sale_dollars             1048575 non-null  float64
#  22  volume_sold_liters       1048575 non-null  float64
#  23  volume_sold_gallons      1048575 non-null  float64
# dtypes: datetime64[ns](1), float64(8), int64(6), object(9)
# memory usage: 192.0+ MB

# %%
df1['Year'] = df1['date'].dt.year.astype('object')
     

# Per Quarter of the Year.
df1['Quarter'] = df1['date'].dt.quarter.astype('object')
     

# Month of the Year.
df1['Month'] = df1['date'].dt.month.astype('object')
     

# Week of the Year.
df1['Week'] = df1['date'].dt.isocalendar().week.astype('object')
     

# Drop 'Date' column as is not needed anymore.
#df = df.drop(columns='Date')

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1048575 entries, 0 to 1048574
# Data columns (total 28 columns):
#  #   Column                   Non-Null Count    Dtype
# ---  ------                   --------------    -----
#  0   invoice_and_item_number  1048575 non-null  object
#  1   date                     1048575 non-null  datetime64[ns]
#  2   store_number             1048575 non-null  int64
#  3   store_name               1048575 non-null  object
#  4   address                  1048511 non-null  object
#  5   city                     1048511 non-null  object
#  6   zip_code                 1048511 non-null  float64
#  7   store_location           930869 non-null   object
#  8   county_number            1048511 non-null  float64
#  9   county                   1048511 non-null  object
#  10  category                 1048575 non-null  int64
#  11  category_name            1048575 non-null  object
#  12  vendor_number            1048572 non-null  float64
#  13  vendor_name              1048572 non-null  object
#  14  item_number              1048575 non-null  int64
#  15  item_description         1048575 non-null  object
#  16  pack                     1048575 non-null  int64
#  17  bottle_volume_ml         1048575 non-null  int64
#  18  state_bottle_cost        1048575 non-null  float64
#  19  state_bottle_retail      1048575 non-null  float64
#  20  bottles_sold             1048575 non-null  int64
#  21  sale_dollars             1048575 non-null  float64
#  22  volume_sold_liters       1048575 non-null  float64
#  23  volume_sold_gallons      1048575 non-null  float64
#  24  Year                     1048575 non-null  object
#  25  Quarter                  1048575 non-null  object
#  26  Month                    1048575 non-null  object
#  27  Week                     1048575 non-null  object
# dtypes: datetime64[ns](1), float64(8), int64(6), object(13)
# memory usage: 224.0+ MB

# %%
df1.drop(columns = ['invoice_and_item_number',
                   'category_name', 'vendor_name',
                   'address', 'zip_code',
                   'store_location', 'category', 'county_number',
                   'vendor_number', 'item_number', 'item_description'],
        inplace = True)

# %%
num_colums=df1.select_dtypes(include = 'number')

# %%
num_colums.columns
# Out:
# Index(['store_number', 'pack', 'bottle_volume_ml', 'state_bottle_cost',
#        'state_bottle_retail', 'bottles_sold', 'sale_dollars',
#        'volume_sold_liters', 'volume_sold_gallons'],
#       dtype='object')

# %%
# fig,axs = plt.subplots(3,3,figsize =(15,15))
# for i, subplots in zip(num_colums,axs.flatten()):
#     sns.boxplot(df1[i],ax=subplots)
#     plt.title('df1[i]',fontsize = 15)
# plt.show()

# %%
for i in num_colums:
    q1,q3 = np.quantile(df1[i],[0.25,0.75])
    iqr = q3 - q1
    ub = q3 + (1.5 * iqr)
    lb = q1 - (1.5 * iqr)
    df1[i] = np.where(df1[i] > ub, ub, df1[i])
    df1[i] = np.where(df1[i] < lb, lb, df1[i])

# %%
fig,axs = plt.subplots(3,3,figsize =(15,15))
for i, subplots in zip(num_colums,axs.flatten()):
    sns.boxplot(df1[i],ax=subplots)
    plt.title('df1[i]',fontsize = 15)
plt.show()

# %%
fig,axs = plt.subplots(3,3,figsize =(15,15))
for i, subplots in zip(num_colums,axs.flatten()):
    sns.violinplot(df1[i],ax=subplots)
    plt.title('df1[i]',fontsize = 15)
plt.show()

# %%
df1.groupby('county').agg(value_count=('county','count')).sort_values(by=['county','value_count'], ascending=[True,False])
# Out:
#            value_count
# county
# ADAIR             1725
# ADAMS             1009
# ALLAMAKEE         3819
# APPANOOSE         3139
# AUDUBON           1461
# ...                ...
# WOODBURY         35495
# WORTH             1600
# WRIGHT            3161
# Wapello           2496
# Webster            821
#
# [119 rows x 1 columns]

# %%
fig,axs = plt.subplots(3,3,figsize =(15,15))
for i, subplots in zip(num_colums,axs.flatten()):
    sns.distplot(df1[i],ax=subplots)
    plt.title('df1[i]',fontsize = 15)
plt.show()

# %%
sns.heatmap(df1.corr(),annot=True)
# Out:
# <AxesSubplot:>
