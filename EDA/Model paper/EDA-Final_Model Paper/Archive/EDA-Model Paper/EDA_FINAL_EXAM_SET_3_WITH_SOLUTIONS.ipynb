# %% [markdown]
# # EDA FINAL EXAM

# %% [markdown]
# ### We combined three datasets in single CSV file mention below columns belongs to
#
#
# ### German Credit Data

# %% [markdown]
# * checkin_acc
# * duration
# * credit_history
# * amount
# * savings_acc
# * present_emp_since
# * inst_rate
# * personal_status
# * residing_since
# * age
# * inst_plans
# * num_credits
# * job
# * status

# %% [markdown]
# ###    data_eda
#
#
# * year
# * region
# * npg
# * birth_rate
# * death_rate
# * migratory_growth
# * population

# %% [markdown]
# ### Indian_cities

# %% [markdown]
# 'name_of_city'                  : Name of the City
#
# 'state_code'                    : State Code of the City
#
# 'state_name'                    : State Name of the City
#
# 'dist_code'                     : District Code where the city belongs ( 99 means multiple district )
#
# 'population_total'              : Total Population
#
# 'population_male'               : Male Population
#
# 'population_female'             : Female Population
#
# '0-6_population_total'          : 0-6 Age Total Population
#
# '0-6_population_male'           : 0-6 Age Male Population
#
#
# '0-6_population_female'         : 0-6 Age Female Population
#
# 'literates_total'               : Total Literates
#
# 'literates_male'                : Male Literates
#
# 'literates_female'              : Female Literates
#
# 'sex_ratio'                     : Sex Ratio
#
# 'child_sex_ratio'               : Sex ratio in 0-6
#
#
#
# 'effective_literacy_rate_total' : Literacy rate over Age 7
#
# 'effective_literacy_rate_male'  : Male Literacy rate over Age 7
#
# 'effective_literacy_rate_female': Female Literacy rate over Age 7
#
# 'location'                      : Lat,Lng
#
# 'total_graduates'               : Total Number of Graduates
#
# 'male_graduates'                : Male Graduates
#
# 'female_graduates'              : Female Graduates

# %%
## Kindly change the below cells from markdown to code and execute it

# %% [markdown]
# import pandas as pd
#
# import csv
#
# with open("data_set.csv","r")as file:
#
#     reader=csv.reader(file)
#
# df=pd.read_csv("data_set.csv")
#
# df.head()

# %%
import numpy as np                  # Scientific Computing
import pandas as pd                 # Data Analysis
import matplotlib.pyplot as plt     # Plotting
import seaborn as sns               # Statistical Data Visualization

# %%
df=pd.read_csv('DA_GM_IC_DATASET.csv')
df.head()
# Out:
#   name_of_city  state_code      state_name  dist_code  population_total  \
# 0      Abohar            3          PUNJAB          9            145238
# 1    Achalpur           27     MAHARASHTRA          7            112293
# 2    Adilabad           28  ANDHRA PRADESH          1            117388
# 3   Adityapur           20       JHARKHAND         24            173988
# 4       Adoni           28  ANDHRA PRADESH         21            166537
#
#    population_male  population_female  0-6_population_total  \
# 0            76840              68398                 15870
# 1            58256              54037                 11810
# 2            59232              58156                 13103
# 3            91495              82493                 23042
# 4            82743              83794                 18406
#
#    0-6_population_male  0-6_population_female  ...  num_credits   job  status  \
# 0                 8587                   7283  ...            2  A173       0
# ...

# %%
df.shape
# Out:
# (493, 43)

# %%
German_Credit_Data = df.iloc[:, 22:36]
German_Credit_Data.head(1)
# Out:
#   checkin_acc  duration credit_history  amount savings_acc present_emp_since  \
# 0         A11         6            A34    1169         A65               A75
#
#    inst_rate personal_status  residing_since  age inst_plans  num_credits  \
# 0          4             A93               4   67       A143            2
#
#     job  status
# 0  A173       0

# %%
data_eda = df.iloc[:, 36:]
data_eda.head(1)
# Out:
#    year              region  npg  birth_rate  death_rate  migratory_growth  \
# 0  1990  Republic of Adygea  1.9        14.2        12.3               NaN
#
#    population
# 0    434788.0

# %%
Indian_cities = df.iloc[:, :22]
Indian_cities.head(1)
# Out:
#   name_of_city  state_code state_name  dist_code  population_total  \
# 0      Abohar            3     PUNJAB          9            145238
#
#    population_male  population_female  0-6_population_total  \
# 0            76840              68398                 15870
#
#    0-6_population_male  0-6_population_female  ...  literates_female  \
# 0                 8587                   7283  ...             44972
#
#    sex_ratio  child_sex_ratio  effective_literacy_rate_total  \
# 0        890              848                          79.86
#
#    effective_literacy_rate_male  effective_literacy_rate_female  \
# 0                         85.49                           73.59
#
#                 location  total_graduates male_graduates  female_graduates
# 0  30.1452928,74.1993043            16287           8612              7675
#
# [1 rows x 22 columns]

# %% [markdown]
# -----------------
# # SECTION A: 20 MARKS
# --------------

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### 1. Read the dataset(German Credit Data) answer the questions below
#
# A) Display the count plot for the 'Status' Column? (1 Marks)
#
# B) Split the dataset into Train and Test. Also give us the reason behind the split (2 Marks)
#
# C) Is the data imbalanced? If so, what types of sampling methods can be used and Write the code for any one type of sampling(No need to execute)? (2 Marks)

# %%
df = German_Credit_Data

# %%
df.head()
# Out:
#   checkin_acc  duration credit_history  amount savings_acc present_emp_since  \
# 0         A11         6            A34    1169         A65               A75
# 1         A12        48            A32    5951         A61               A73
# 2         A14        12            A34    2096         A61               A74
# 3         A11        42            A32    7882         A61               A74
# 4         A11        24            A33    4870         A61               A73
#
#    inst_rate personal_status  residing_since  age inst_plans  num_credits  \
# 0          4             A93               4   67       A143            2
# 1          2             A92               2   22       A143            1
# 2          2             A93               3   49       A143            1
# 3          2             A93               4   45       A143            1
# 4          3             A93               4   53       A143            2
#
#     job  status
# 0  A173       0
# 1  A173       1
# ...

# %% [markdown]
# #### 2. A) Draw the Count Plot for the Status Column? (1 Marks)

# %%
sns.countplot(x="status", data=df)

# %% [markdown]
# ##### B) Split the Dataset into Train and Test. Also give us the reason behind your split
#
#    Assume Status Column to be the Target variable? (2 Marks)

# %%
from sklearn.model_selection import train_test_split

# %%
X=df.drop(['status'],axis=1)
y=df.status

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.7, test_size = 0.3, random_state=100)

# %% [markdown]
# ##### C) Is the Data imbalanced . If so what types of Sampling methods can be used and Write the code for any one type of Sampling (No need to execute)? (2 Marks)

# %% [markdown]
#     The Status column is imbalanced.
#     There are two types of techniques which we can use to treat imbalanced - Oversampling and Undersampling.

# %% [markdown]
# #Oversampling
# from imblearn.over_sampling import SMOTE
# X, y = SMOTE().fit_resample(X, y)
# from collections import Counter
# print(sorted(Counter(y).items()))

# %% [markdown]
# ### 2. Read the dataset(German Credit Data.csv) answer the questions below
#
# A) Display the count plot for 'Checkin_acc' column? (1 Marks)
#
# B) How does the distribution of the 'Age' column look like? Perform the Normality test on Age. (2 Marks)
#
# C) How do you handle object variables? Write down the code for encoding? (2 Marks)

# %%
df = German_Credit_Data

# %%
df.head()
# Out:
#   checkin_acc  duration credit_history  amount savings_acc present_emp_since  \
# 0         A11         6            A34    1169         A65               A75
# 1         A12        48            A32    5951         A61               A73
# 2         A14        12            A34    2096         A61               A74
# 3         A11        42            A32    7882         A61               A74
# 4         A11        24            A33    4870         A61               A73
#
#    inst_rate personal_status  residing_since  age inst_plans  num_credits  \
# 0          4             A93               4   67       A143            2
# 1          2             A92               2   22       A143            1
# 2          2             A93               3   49       A143            1
# 3          2             A93               4   45       A143            1
# 4          3             A93               4   53       A143            2
#
#     job  status
# 0  A173       0
# 1  A173       1
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 493 entries, 0 to 492
# Data columns (total 14 columns):
# checkin_acc          493 non-null object
# duration             493 non-null int64
# credit_history       493 non-null object
# amount               493 non-null int64
# savings_acc          493 non-null object
# present_emp_since    493 non-null object
# inst_rate            493 non-null int64
# personal_status      493 non-null object
# residing_since       493 non-null int64
# age                  493 non-null int64
# inst_plans           493 non-null object
# num_credits          493 non-null int64
# job                  493 non-null object
# status               493 non-null int64
# dtypes: int64(7), object(7)
# memory usage: 54.0+ KB

# %% [markdown]
#  A) Draw the Count Plot for Checkin_acc Column? (1 Marks)

# %%
sns.countplot(x="checkin_acc", data=df)

# %% [markdown]
#  B)How does the distribution of Age columns look like and perform the corresponding statistical test ?(2 Marks)

# %%
sns.distplot( df['age']);

# %%
from scipy import stats
stats.shapiro(df['age'])
# Out:
# (0.9135161638259888, 3.6186380413270663e-16)

# %% [markdown]
# Shapiro test pvalue saying that it not normal

# %% [markdown]
# C) Based on the type of categorical column appropriate encoding techniques should be applied (2 Marks)

# %%
categorical = df.select_dtypes(include=['object'])

# %%
categorical.columns
# Out:
# Index(['checkin_acc', 'credit_history', 'savings_acc', 'present_emp_since',
#        'personal_status', 'inst_plans', 'job'],
#       dtype='object')

# %%
from sklearn import preprocessing
le = preprocessing.LabelEncoder()
df_categorical = categorical.apply(le.fit_transform)
df_categorical.head()
# Out:
#    checkin_acc  credit_history  savings_acc  present_emp_since  \
# 0            0               4            4                  4
# 1            1               2            0                  2
# 2            3               4            0                  3
# 3            0               2            0                  3
# 4            0               3            0                  2
#
#    personal_status  inst_plans  job
# 0                2           2    2
# 1                1           2    2
# 2                2           2    1
# 3                2           2    2
# 4                2           2    2

# %%
#use one hot encoding for nominal data
#use label encoding for ordinal data
df = pd.read_csv('German Credit Data.csv')
df_dum=pd.get_dummies(df)

# %% [markdown]
# ### 3.  Read the dataset(data_eda) answer the questions below
#
#
#
#  a. Check if there is any correlation between the variables and write down your observations. (3 marks)
#
#  b. Identify regions which saw an increase or decrease in migration using appropriate plots. (2 marks)

# %%
data = data_eda
data.head()
# Out:
#    year              region  npg  birth_rate  death_rate  migratory_growth  \
# 0  1990  Republic of Adygea  1.9        14.2        12.3               NaN
# 1  1990          Altai Krai  1.8        12.9        11.1               NaN
# 2  1990         Amur Oblast  7.6        16.2         8.6               NaN
# 3  1990  Arkhangelsk Oblast  3.7        13.5         9.8               NaN
# 4  1990    Astrakhan Oblast  4.7        15.1        10.4               NaN
#
#    population
# 0    434788.0
# 1   2640419.0
# 2   1055337.0
# 3   1523509.0
# 4    997516.0

# %% [markdown]
# ##### A.	Check if there is correlation between the variables and write down your observations. (3 marks)

# %% [markdown]
# **Correlation hearmap**

# %%
correlations = data.corr()

fig = plt.figure(figsize=(12, 10))
sns.heatmap(correlations, annot=True, cmap='GnBu_r', center=1)

# %% [markdown]
# * Birth rate and NPG have high positive correlation
# * Death rate and NPG have high negative correlation, and that is perfectly valid

# %% [markdown]
# ##### b.	Identify regions which saw an increase or decrease in migration using appropriate plots. (2 marks)

# %%
data.groupby(['region']).agg({'migratory_growth':'mean'}).sort_values(by='migratory_growth',ascending=False).plot.bar(figsize=(20,10))

# %% [markdown]
# ### 4. Read the dataset(data_eda) answer the questions below

# %% [markdown]
# ##### A.	Identify the trend in the growth of population using appropriate plots and write down the observations based on increase or decrease in population over the years. (5 marks)

# %%
data.groupby(['year']).agg({'npg':'mean'}).plot.bar(figsize=(20,5))
plt.show()

# %% [markdown]
# From the above plot, we can see that there is a decline in natural population growth over the years.

# %% [markdown]
# **Relationship between "birth_rate" and "npg" (nearly perfect correlation)**

# %%
sns.regplot(data.birth_rate, data.npg, color='red')
plt.axvline(data.birth_rate.mean(), linestyle = "dashed", color ="black", label ="Mean value for the birth_rate")
plt.axhline(data.npg.mean(), linestyle = "dashed", color ="blue", label ="Mean value for the npg")

plt.legend()

# %% [markdown]
# ---------------
# # SECTION B: 20 MARKS
# ------------

# %% [markdown]
# ### 5. Read the dataset(data_eda) answer the questions below
#
#  A. Separate categorical data and numerical data and create new dataframe for each(5 Marks)
#
#  B. Display the count of each variable, null values, distinct values, missing_ratio, skewness and kurtosis in a tabular form. (9 marks)
#
#  C. Plot the distribution of npg, migratory_growth, birth_date and death_rate and check for outliers. Impute the missing values for the column which has more than 25% missing ratio. (6 marks)"

# %% [markdown]
# ##### A. Separate categorical data and numerical data and create new dataframe for each(5 Marks)

# %%
data = data_eda

# %%
cat_cols = data.select_dtypes(include = 'object')
num_cols = data.select_dtypes(include = np.number)
print('Continuous variables are : ',num_cols.columns)
print('Categorical Columns are : ',cat_cols.columns)
# Out:
# Continuous variables are :  Index(['year', 'npg', 'birth_rate', 'death_rate', 'migratory_growth',
#        'population'],
#       dtype='object')
# Categorical Columns are :  Index(['region'], dtype='object')

# %%
print('% Values in each categorical columns')
for i in cat_cols.columns:
    print('\n% Values in column ',i)
    print((data[i].value_counts()/len(data[i])*100))
# Out:
# % Values in each categorical columns
#
# % Values in column  region
# Tuva Republic                            1.217039
# Karachay-Cherkess Republic               1.217039
# Altai Krai                               1.217039
# Republic of Buryatia                     1.217039
# Moscow                                   1.217039
# Zabaykalsky Krai                         1.217039
# Amur Oblast                              1.217039
# Oryol Oblast                             1.217039
# Kostroma Oblast                          1.217039
# Republic of Dagestan                     1.217039
# Kabardino-Balkar Republic                1.217039
# Saint Petersburg                         1.217039
# Kursk Oblast                             1.217039
# Penza Oblast                             1.217039
# Arkhangelsk Oblast                       1.217039
# Novosibirsk Oblast                       1.217039
# Kaliningrad Oblast                       1.217039
# ...

# %%
data.head()
# Out:
#    year              region  npg  birth_rate  death_rate  migratory_growth  \
# 0  1990  Republic of Adygea  1.9        14.2        12.3               NaN
# 1  1990          Altai Krai  1.8        12.9        11.1               NaN
# 2  1990         Amur Oblast  7.6        16.2         8.6               NaN
# 3  1990  Arkhangelsk Oblast  3.7        13.5         9.8               NaN
# 4  1990    Astrakhan Oblast  4.7        15.1        10.4               NaN
#
#    population
# 0    434788.0
# 1   2640419.0
# 2   1055337.0
# 3   1523509.0
# 4    997516.0

# %% [markdown]
# Function which shows us types, missing ratio, counts and other things

# %% [markdown]
# ##### B.	Display the count of each variables, null values, distinct values, missing_ratio, skewness and kurtosis in a tabular form (9 marks)

# %%
def detailed_analysis(df):
  obs = df.shape[0]
  types = df.dtypes
  counts = df.apply(lambda x: x.count())
  uniques = df.apply(lambda x: [x.unique()])
  nulls = df.apply(lambda x: x.isnull().sum())
  distincts = df.apply(lambda x: x.unique().shape[0])
  missing_ratio = (df.isnull().sum() / obs) * 100
  skewness = df.skew()
  kurtosis = df.kurt()
  print('Data shape:', df.shape)

  cols = ['types', 'counts', 'nulls', 'distincts', 'missing ratio', 'uniques', 'skewness', 'kurtosis']
  details = pd.concat([types, counts, nulls, distincts, missing_ratio, uniques, skewness, kurtosis], axis=1, sort=False)
  
  details.columns = cols
  dtypes = details.types.value_counts()
  print('____________________________\nData types:\n', dtypes)
  print('____________________________')
  return details

# %%
details = detailed_analysis(data)
details
# Out:
# Data shape: (493, 7)
# ____________________________
# Data types:
#  float64    5
# int64      1
# object     1
# Name: types, dtype: int64
# ____________________________
#                     types  counts  nulls  distincts  missing ratio  \
# year                int64     493      0          6       0.000000
# region             object     493      0         85       0.000000
# npg               float64     474     19        210       3.853955
# birth_rate        float64     474     19        123       3.853955
# death_rate        float64     474     19        139       3.853955
# migratory_growth  float64       0    493          1     100.000000
# population        float64     483     10        484       2.028398
#
#                                                             uniques  skewness  \
# year                         [[1990, 1991, 1992, 1993, 1994, 1995]]  0.039622
# region            [[Republic of Adygea, Altai Krai, Amur Oblast,...       NaN
# ...

# %%
data.describe()
# Out:
#               year         npg  birth_rate  death_rate  migratory_growth  \
# count   493.000000  474.000000  474.000000  474.000000               0.0
# mean   1992.413793   -1.088397   11.574051   12.662447               NaN
# std       1.673312    6.098166    3.343559    3.300942               NaN
# min    1990.000000  -14.700000    6.600000    3.300000               NaN
# 25%    1991.000000   -5.500000    9.100000   10.400000               NaN
# 50%    1992.000000   -2.000000   10.850000   12.900000               NaN
# 75%    1994.000000    2.700000   13.000000   14.900000               NaN
# max    1995.000000   19.900000   26.300000   22.700000               NaN
#
#          population
# count  4.830000e+02
# mean   1.794576e+06
# std    1.519293e+06
# min    4.452600e+04
# 25%    8.368645e+05
# 50%    1.335735e+06
# 75%    2.470300e+06
# max    9.085457e+06

# %% [markdown]
# ##### C. Plot the distribution of npg, migratory_growth, birth_date and death_rate and check for outliers. Impute the missing values for the column which has more than 25% missing ratio. (6 Marks)

# %% [markdown]
# **DIstribution of some features**

# %%
fig = plt.figure(figsize=(30, 15))
features = ['npg', 'migratory_growth', 'birth_rate', 'death_rate']
colors = ['g', 'r', 'b', 'orange']

for x in range(len(features)):
    fig1 = fig.add_subplot(2, 2, x + 1)
    sns.boxplot(data[features[x]], color=colors[x])
    plt.axvline(data[features[x]].mean(), linestyle = "dashed", color ="black", label ="Mean value for the data")
    plt.legend()

# %%
data['migratory_growth'].fillna(data['migratory_growth'].median(),inplace=True)

# %% [markdown]
# ------------
# # SECTION C: 30 MARKS
#
# -------------------

# %% [markdown]
# ### 6. Read the dataset(Indian_cities) answer the questions below
#
#
#  a. Plot the distribution of sex ratio and child-sex ratio and state your observations. (Use two separate plots) (5 marks)
#
#  b. Identify the top 5 and bottom 5 cities in terms of the number of female graduates (Use two separate plots (5 marks)"

# %%
df = Indian_cities

# %%
df.head()
# Out:
#   name_of_city  state_code      state_name  dist_code  population_total  \
# 0      Abohar            3          PUNJAB          9            145238
# 1    Achalpur           27     MAHARASHTRA          7            112293
# 2    Adilabad           28  ANDHRA PRADESH          1            117388
# 3   Adityapur           20       JHARKHAND         24            173988
# 4       Adoni           28  ANDHRA PRADESH         21            166537
#
#    population_male  population_female  0-6_population_total  \
# 0            76840              68398                 15870
# 1            58256              54037                 11810
# 2            59232              58156                 13103
# 3            91495              82493                 23042
# 4            82743              83794                 18406
#
#    0-6_population_male  0-6_population_female  ...  literates_female  \
# 0                 8587                   7283  ...             44972
# ...

# %%
df.describe()
# Out:
#        state_code   dist_code  population_total  population_male  \
# count  493.000000  493.000000      4.930000e+02     4.930000e+02
# mean    18.643002   16.782961      4.481124e+05     2.343468e+05
# std      9.297168   15.566131      1.033228e+06     5.487786e+05
# min      1.000000    1.000000      1.000360e+05     5.020100e+04
# 25%      9.000000    7.000000      1.261420e+05     6.638400e+04
# 50%     19.000000   13.000000      1.841330e+05     9.665500e+04
# 75%     27.000000   21.000000      3.490330e+05     1.750550e+05
# max     35.000000   99.000000      1.247845e+07     6.736815e+06
#
#        population_female  0-6_population_total  0-6_population_male  \
# count       4.930000e+02          4.930000e+02           493.000000
# mean        2.137656e+05          4.709285e+04         24849.527383
# std         4.848622e+05          1.050279e+05         55535.310272
# min         4.512600e+04          6.547000e+03          3406.000000
# ...

# %%
# describing the data types
df.dtypes
# Out:
# name_of_city                       object
# state_code                          int64
# state_name                         object
# dist_code                           int64
# population_total                    int64
# population_male                     int64
# population_female                   int64
# 0-6_population_total                int64
# 0-6_population_male                 int64
# 0-6_population_female               int64
# literates_total                     int64
# literates_male                      int64
# literates_female                    int64
# sex_ratio                           int64
# child_sex_ratio                     int64
# effective_literacy_rate_total     float64
# effective_literacy_rate_male      float64
# effective_literacy_rate_female    float64
# location                           object
# total_graduates                     int64
# male_graduates                      int64
# female_graduates                    int64
# dtype: object

# %% [markdown]
# ##### a.	Plot the distribution of sex ratio and child-sex ratio and state your observations

# %%
# Histogram plot of Sex Ratio. The plot is near to normal..

figure = plt.figure(figsize=(15,8))
plt.hist(df['sex_ratio'],color = 'olive',bins = 30)
plt.xlabel('sex_ratio')
plt.ylabel('count of cities')
plt.title('Histogram of Sex-ratio')
# Out:
# Text(0.5, 1.0, 'Histogram of Sex-ratio')

# %%
# Histogram plot of Child Sex Ratio. The plot is near to normal..

figure = plt.figure(figsize=(15,8))
plt.hist(df['child_sex_ratio'],color = 'skyblue',bins = 30)
plt.xlabel('sex_ratio')
plt.ylabel('count of cities')
plt.title('Histogram of Child-Sex-ratio')
# Out:
# Text(0.5, 1.0, 'Histogram of Child-Sex-ratio')

# %%
# the distribution of Child sex ratio 

sns.distplot(df['child_sex_ratio'],rug = True)

# %% [markdown]
# ##### b.	Identify the top 5 and bottom 5 cities in terms of the number of female graduates (5 marks)

# %%
# Best 5 cities with highest number of female graduates

data_female_graduates_best_city = pd.DataFrame(df['female_graduates'].groupby(df['name_of_city']).mean().sort_values(ascending = False)[:5])
data_female_graduates_best_city['city_name'] = data_female_graduates_best_city.index.values
data_female_graduates_best_city
# Out:
#                     female_graduates           city_name
# name_of_city
# Delhi                        1011097              Delhi
# Greater Mumbai                837407     Greater Mumbai
# Bengaluru                     682800           Bengaluru
# Greater Hyderabad             478747  Greater Hyderabad
# Chennai                       392267            Chennai

# %%
#5 cities with lowest number of female graduates

data_female_graduates_worst_city = pd.DataFrame(df['female_graduates'].groupby(df['name_of_city']).mean().sort_values()[:5])
data_female_graduates_worst_city['city_name'] = data_female_graduates_worst_city.index.values
data_female_graduates_worst_city
# Out:
#               female_graduates    city_name
# name_of_city
# Dabgram                    829     Dabgram
# Bagaha                     988      Bagaha
# Jamuria                   1475     Jamuria
# Pithampur                 1493   Pithampur
# Mustafabad                1512  Mustafabad

# %% [markdown]
# ### 7. Read the dataset(Indian_cities) answer the questions below
#
#
#  a. Plot the 5 states having lowest sex ratio (3 marks)
#
#  b. Identify the top 5 cities which have higher ratio of male to female effective literacy rate (2 marks)
#
#
#  c. Split the column location into two columns ‘latitude’ and ‘longitude’ and replace the location column with the two newly created columns in the original dataframe. (5 marks)"

# %% [markdown]
# ##### A.	Plot the 5 states having lowest sex ratio (3 marks)

# %%
df['sex_ratio'].groupby(df['state_name']).mean().sort_values()
# Out:
# state_name
# HIMACHAL PRADESH              818.000000
# CHANDIGARH                    829.000000
# NCT OF DELHI                  861.533333
# HARYANA                       875.800000
# PUNJAB                        887.062500
# BIHAR                         887.884615
# ANDAMAN & NICOBAR ISLANDS     889.000000
# UTTAR PRADESH                 891.285714
# UTTARAKHAND                   892.333333
# JHARKHAND                     903.000000
# NAGALAND                      904.000000
# JAMMU & KASHMIR               907.666667
# RAJASTHAN                     908.517241
# GUJARAT                       913.172414
# MADHYA PRADESH                914.812500
# MAHARASHTRA                   920.511628
# ORISSA                        930.300000
# WEST BENGAL                   943.262295
# CHHATTISGARH                  950.222222
# ASSAM                         950.750000
# KARNATAKA                     987.115385
# ANDHRA PRADESH                999.404762
# ...

# %%
data_sex = pd.DataFrame(df['sex_ratio'].groupby(df['state_name']).mean().sort_values()[:5])
data_sex
# Out:
#                    sex_ratio
# state_name
# HIMACHAL PRADESH  818.000000
# CHANDIGARH        829.000000
# NCT OF DELHI      861.533333
# HARYANA           875.800000
# PUNJAB            887.062500

# %%
# to covert index into column
data_sex['state'] = data_sex.index.values 

fig = plt.figure(figsize=(15,10))
ax = fig.add_subplot(111)
N = len(data_sex['sex_ratio'])
y = data_sex['sex_ratio']
x = range(N)
plt.bar(x,y,width = 0.5,color = "darkblue")
ax.set_xticklabels(data_sex['state'])
ax.set_xlabel('states')
ax.set_title('States having lowest Sex-Ratio')
# Out:
# Text(0.5, 1.0, 'States having lowest Sex-Ratio')

# %% [markdown]
# ##### b.	Identify the top 5 cities which have higher ratio of male to female effective literacy rate (2 marks)

# %%
# Top 5 cities with highest ratio of male_female effective litereacy rate
df['ratio_male_female_eff_literacy_rate']=df['effective_literacy_rate_male']/df['effective_literacy_rate_female']

# %%
data_ratio_male_female_eff_literacy_rate = pd.DataFrame(df['ratio_male_female_eff_literacy_rate'].groupby(df['name_of_city']).mean().sort_values(ascending =False)[:5])
data_ratio_male_female_eff_literacy_rate
# Out:
#                 ratio_male_female_eff_literacy_rate
# name_of_city
# Hindaun                                    1.373006
# Churu                                      1.371175
# Bagaha                                     1.364442
# Sujangarh                                  1.357120
# Gangapur City                              1.344787

# %% [markdown]
# ##### c.	Split the column location into two columns ‘latitude’ and ‘longitude’ and replace the location column with the two newly created columns in the original dataframe. (5 marks)

# %%
##to split columns in a dataframe:
df1 = df.join(df['location'].str.split(',',expand=True).rename(columns = {0:'Latitude',1:'longitude'}))

# %%
df1
# Out:
#            name_of_city  state_code      state_name  dist_code  \
# 0               Abohar            3          PUNJAB          9
# 1             Achalpur           27     MAHARASHTRA          7
# 2             Adilabad           28  ANDHRA PRADESH          1
# 3            Adityapur           20       JHARKHAND         24
# 4                Adoni           28  ANDHRA PRADESH         21
# 5             Agartala           16         TRIPURA          1
# 6                 Agra            9   UTTAR PRADESH         15
# 7            Ahmadabad           24         GUJARAT          7
# 8           Ahmadnagar           27     MAHARASHTRA         26
# 9               Aizawl           15         MIZORAM          3
# 10               Ajmer            8       RAJASTHAN         21
# 11            Akbarpur            9   UTTAR PRADESH         47
# 12               Akola           27     MAHARASHTRA          5
# 13             Alandur           33      TAMIL NADU          3
# ...
