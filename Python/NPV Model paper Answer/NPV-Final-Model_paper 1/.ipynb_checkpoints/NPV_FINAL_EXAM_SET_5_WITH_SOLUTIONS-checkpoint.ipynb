# %% [markdown]
# # NPV FINAL EXAM

# %% [markdown]
# ### 1. Report_2010_to_Congress_on_White_House_Staff

# %% [markdown]
# * Employee Name
# * Employee Status
# * Salary
# * Pay Basis
# * Position Title

# %% [markdown]
# ### 2. chipotle

# %% [markdown]
# * order_id
# * quantity
# * item_name
# * choice_description
# * item_price

# %% [markdown]
# ### 3. Euro_2012_stats_TEAM

# %% [markdown]
# * Team
# * Goals
# * Shots on target
# * Shots off target
# * Shooting Accuracy
# * % Goals-to-shots
# * Total shots (inc. Blocked)
# * Hit Woodwork
# * Penalty goals
# * Penalties not scored
# * Headed goals
# * Passes
# * Passes completed
# * Passing Accuracy
# * Touches
# * Crosses
# * Dribbles
# * Corners Taken
# * Tackles
# * Clearances
# * Interceptions
# * Clearances off line
# * Clean Sheets
# * Blocks
# * Goals conceded
# * Saves made
# * Saves-to-shots ratio
# * Fouls Won
# * Fouls Conceded
# * Offsides
# * Yellow Cards
# * Red Cards
# * Subs on
# * Subs off
# * Players Used

# %% [markdown]
# ### 4. hotdogs

# %% [markdown]
# * Beef
# * 186
# * 495

# %% [markdown]
# ### 5. stock_data

# %% [markdown]
# * Unknow column
# * AA
# * AAPL
# * GE
# * IBM
# * JNJ
# * MSFT
# * PEP
# * SPX
# * XOM

# %% [markdown]
# ### 6. Fifa

# %% [markdown]
# ID: unique id for every player
#
# Name: name
#
# Age: age
#
# Nationality: nationality
#
# Overall: overall rating
#
# Potential: potential rating
#
# Club: current club
#
# Value: current market value
#
# Wage: current wage
#
# Special: special
#
# Preferred Foot: left/right
#
# International Reputation: rating on scale of 5
#
# Weak Foot: rating on scale of 5
#
# Skill Moves: rating on scale of 5
#
# Work Rate: attack work rate/defense work rate
#
# Body Type: body type of player
#
# Real Face: true or false
#
# Position: position on the pitch
#
#
# Jersey Number: jersey number
#
# Joined: joined date
#
# Contract Valid Until: contract end date
#
# Height: height of the player
#
# Weight: weight of the player

# %% [markdown]
# ### We combined Two datasets in single CSV file and mention below columns belongs to

# %%
## Kindly change the below cells from markdown to code and execute it

# %% [markdown]
# import pandas as pd
#
# import csv
#
# with open("data_set.csv","r")as file:
#
#     reader=csv.reader(file)
#
# df=pd.read_csv("data_set.csv")
#
# df.head()

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import math

# %%
df=pd.read_csv("DATASET.csv",encoding='latin1')
df.head(2)
# Out:
#      Employee Name Employee Status  Salary  Pay Basis  \
# 0  Abrams, Adam W.        Employee   66300  Per Annum
# 1    Adams, Ian H.        Employee   45000  Per Annum
#
#                                       Position Title  order_id  quantity  \
# 0           WESTERN REGIONAL COMMUNICATIONS DIRECTOR         1         1
# 1  EXECUTIVE ASSISTANT TO THE DIRECTOR OF SCHEDUL...         1         1
#
#                       item_name choice_description item_price  ...  \
# 0  Chips and Fresh Tomato Salsa                NaN     $2.39   ...
# 1                          Izze       [Clementine]     $3.39   ...
#
#   Skill Moves       Work Rate  Body Type  Real Face Position Jersey Number  \
# 0           3  Medium/ Medium       Lean         No      RCM            10
# 1           4    High/ Medium     Normal        Yes       LF             8
#
#       Joined  Contract Valid Until  Height  Weight
# 0  19-Jul-14                  2019    5'10  143lbs
# 1  16-Jul-18                  2021     5'7  150lbs
#
# [2 rows x 81 columns]

# %%
Report_2010_to_Congress_on_White_House_Staff = df.iloc[:, :5]
Report_2010_to_Congress_on_White_House_Staff.head(1)
# Out:
#      Employee Name Employee Status  Salary  Pay Basis  \
# 0  Abrams, Adam W.        Employee   66300  Per Annum
#
#                              Position Title
# 0  WESTERN REGIONAL COMMUNICATIONS DIRECTOR

# %%
chipotle = df.iloc[:, 5:10]
chipotle.head(1)
# Out:
#    order_id  quantity                     item_name choice_description  \
# 0         1         1  Chips and Fresh Tomato Salsa                NaN
#
#   item_price
# 0     $2.39

# %%
Euro_2012_stats_TEAM = df.iloc[:, 10:45]
Euro_2012_stats_TEAM.head(1)
# Out:
#       Team  Goals  Shots on target  Shots off target Shooting Accuracy  \
# 0  Croatia      4               13                12            51.90%
#
#   % Goals-to-shots  Total shots (inc. Blocked)  Hit Woodwork  Penalty goals  \
# 0           16.00%                          32             0              0
#
#    Penalties not scored  ...  Saves made  Saves-to-shots ratio  Fouls Won  \
# 0                     0  ...          13                81.30%         41
#
#   Fouls Conceded  Offsides  Yellow Cards  Red Cards  Subs on  Subs off  \
# 0             62         2             9          0        9         9
#
#    Players Used
# 0            16
#
# [1 rows x 35 columns]

# %%
hotdogs = df.iloc[:, 45:48]
hotdogs.head(1)
# Out:
#    Beef  186  495
# 0  Beef  181  477

# %%
stock_data = df.iloc[:, 48:58]
stock_data.head(1)
# Out:
#         Unnamed: 48     AA    AAPL     GE     IBM    JNJ   MSFT    PEP  \
# 0  29-10-2007 00:00  37.41  185.09  34.46  106.78  57.13  31.78  65.67
#
#        SPX    XOM
# 0  1540.98  85.51

# %%
Fifa= df.iloc[:, 58:]
Fifa.head(1)
# Out:
#    ID         Name  Age Nationality  Overall  Potential       Club  Value  \
# 0  16  Luis Garc¡a   37       Spain       71         71  KAS Eupen  ?750K
#
#   Wage  Special  ... Skill Moves       Work Rate  Body Type  Real Face  \
# 0  ?6K     1906  ...           3  Medium/ Medium       Lean         No
#
#   Position Jersey Number     Joined Contract Valid Until  Height  Weight
# 0      RCM            10  19-Jul-14                 2019    5'10  143lbs
#
# [1 rows x 23 columns]

# %% [markdown]
#  _________________

# %% [markdown]
# # SECTION A: 20 MARKS

# %% [markdown]
#  _________________

# %% [markdown]
# ### 1. Read the dataset(Report_2010_to_Congress_on_White_House_Staff) and Answer the below questions?
#
# A. Find the salary of an employee in a (1st-row 2nd-column) using a position based indexing function? (1 Mark)
#
# B. Display all the employees whose salary is greater than 50000?(1 Mark)
#
# C. Display all the rows whose salary is greater than 50000 and position as "ANALYST"?(1 Mark)
#
# D. Find the list of Employee details belonging to a position ('ANALYST','ADVISOR')?(1 Mark)
#
# E. Find the top 10 highest-paid employees in each position?(1 Mark)

# %%
data=Report_2010_to_Congress_on_White_House_Staff
data.head()
# Out:
#           Employee Name Employee Status  Salary  Pay Basis  \
# 0       Abrams, Adam W.        Employee   66300  Per Annum
# 1         Adams, Ian H.        Employee   45000  Per Annum
# 2       Agnew, David P.        Employee   93840  Per Annum
# 3        Albino, James         Employee   91800  Per Annum
# 4  Aldy, Jr., Joseph E.        Employee  130500  Per Annum
#
#                                       Position Title
# 0           WESTERN REGIONAL COMMUNICATIONS DIRECTOR
# 1  EXECUTIVE ASSISTANT TO THE DIRECTOR OF SCHEDUL...
# 2       DEPUTY DIRECTOR OF INTERGOVERNMENTAL AFFAIRS
# 3                             SENIOR PROGRAM MANAGER
# 4  SPECIAL ASSISTANT TO THE PRESIDENT FOR ENERGY ...

# %% [markdown]
# #### A. Find the salary of an employee in a 1st-row 2nd column using a position based indexing function?

# %%
data.iloc[1,2]
# Out:
# 45000

# %% [markdown]
# #### B. Display all the employees whose salary is greater than 50000?

# %%
data.Salary>50000
transformed_df=data[data.Salary>50000]
transformed_df.head(2)
# Out:
#      Employee Name Employee Status  Salary  Pay Basis  \
# 0  Abrams, Adam W.        Employee   66300  Per Annum
# 2  Agnew, David P.        Employee   93840  Per Annum
#
#                                  Position Title
# 0      WESTERN REGIONAL COMMUNICATIONS DIRECTOR
# 2  DEPUTY DIRECTOR OF INTERGOVERNMENTAL AFFAIRS

# %% [markdown]
# #### C.  Display all the rows whose salary is greater than 50000 and position as "ANALYST"?

# %%
transformed_df2=data[(data.Salary>50000) & (data['Position Title'] == 'ANALYST')]
transformed_df2
# Out:
#     Employee Name Employee Status  Salary  Pay Basis Position Title
# 453   White, Cleo        Detailee   65393  Per Annum        ANALYST

# %% [markdown]
# #### D. Find the list of Employee details belonging to a position ('ANALYST','ADVISOR')?

# %%
transformed_df3=data[data['Position Title'].isin(['ANALYST','ADVISOR'])]
transformed_df3
# Out:
#              Employee Name Employee Status  Salary  Pay Basis Position Title
# 14      Ayling, Lindsay A.        Employee   42000  Per Annum        ANALYST
# 55        Campos, David R.        Employee   42000  Per Annum        ANALYST
# 63      Castillo, Laura M.        Employee   42000  Per Annum        ANALYST
# 104      Dorsett, Craig M.        Employee   42000  Per Annum        ANALYST
# 154      Grant, Kathryn A.        Employee   42000  Per Annum        ANALYST
# 167       Hegde, Shilpa S.        Employee   42000  Per Annum        ANALYST
# 277  McGinnis, Patricia G.        Employee       0  Per Annum        ADVISOR
# 284       Metcalf, Ryan D.        Employee   42000  Per Annum        ANALYST
# 338       Posey, Stacie M.        Employee   42000  Per Annum        ANALYST
# 353      Robertson, Ian T.        Employee   42000  Per Annum        ANALYST
# 373     Schaub, Matthew J.        Employee   42000  Per Annum        ANALYST
# 434       Utech, Daniel G.        Detailee  130000  Per Annum        ADVISOR
# 453            White, Cleo        Detailee   65393  Per Annum        ANALYST

# %% [markdown]
# #### E. Find the top 10 highest-paid employees in each position?

# %%
df_bypositiontitle=data.groupby('Position Title')
df_bypositiontitle[['Employee Name','Salary']].max().head(10)
# Out:
#                                            Employee Name  Salary
# Position Title
# ADVANCE COORDINATOR                  Faulman, Michael T.   42000
# ADVISOR                                 Utech, Daniel G.  130000
# ANALYST                                      White, Cleo   65393
# ASSISTANT COUNSEL FOR NOMINATIONS       Kumar, Pravin D.   50000
# ASSISTANT DIRECTOR                      Stracko, Jill A.   66300
# ASSISTANT EXECUTIVE CLERK          Thomas, III, Edwin R.  106839
# ASSISTANT PRESS SECRETARY              Vietor, Thomas F.   78000
# ASSISTANT SHIFT LEADER                     Sass, Joan C.   63673
# ASSISTANT SPEECHWRITER                 O'Connor, Kyle P.   42000
# ASSISTANT STAFF SECRETARY                 Walsh, Joan L.   60000

# %% [markdown]
# ### 2. Read the dataset(chipotle)
#
# A. Select only the products with quantity equals to 1.  (1 marks)
#
# B. Count the item_price is greater than 10(1 mark)
#
# C. Find How many times Veggie Salad Bowl ordered? (1 mark)
#
# D. Find the quantity of the most expensive item ordered? (2 mark)

# %%
chipo = chipotle
chipo.head(2)
# Out:
#    order_id  quantity                     item_name choice_description  \
# 0         1         1  Chips and Fresh Tomato Salsa                NaN
# 1         1         1                          Izze       [Clementine]
#
#   item_price
# 0     $2.39
# 1     $3.39

# %% [markdown]
# #### A. Select only the products with quantity equals to 1. (1 marks)

# %%
prices = [float(value[1 : -1]) for value in chipo.item_price]

# reassign the column with the cleaned prices
chipo.item_price = prices

# %%
chipo_filtered = chipo.drop_duplicates(['item_name','quantity'])

# %%
chipo_one_prod = chipo_filtered[chipo_filtered.quantity == 1]
chipo_one_prod.head()
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 5         3         1                           Chicken Bowl
#
#                                   choice_description  item_price
# 0                                                NaN        2.39
# 1                                       [Clementine]        3.39
# 2                                            [Apple]        3.39
# 3                                                NaN        2.39
# 5  [Fresh Tomato Salsa (Mild), [Rice, Cheese, Sou...       10.98

# %% [markdown]
# #### B count the item_price is greater then 10(1 mark)

# %%
chipo_one_prod[chipo_one_prod['item_price']>10].item_name.nunique()
# Out:
# 8

# %% [markdown]
# #### C find How many times Veggie Salad Bowl ordered?(1 mark)

# %%
chipo_salad = chipo[chipo.item_name == "Veggie Salad Bowl"]

len(chipo_salad)
# Out:
# 3

# %% [markdown]
# #### D. find the quantity of the most expensive item ordered?(2 mark)

# %%
chipo.sort_values(by = "item_price", ascending = False).head(1)
# Out:
#      order_id  quantity     item_name  \
# 409       178         3  Chicken Bowl
#
#                                     choice_description  item_price
# 409  [[Fresh Tomato Salsa (Mild), Tomatillo-Green C...       32.94

# %% [markdown]
# ### 3. Read the dataset(Euro_2012_stats_TEAM.CSV)
#
# A. How many teams participated in the Euro2012 dataset.  (1 mark)
#
# B. Create a data frame with a name "discipline" consisting of (Team, Yellow Cards and Red Cards) (1 mark)
# C. Find average Yellow Cards given per Team (1 mark)
#
# D. Find which teams  scored more than 6 goals(1 mark)
#
# E. Display the teams start with " G "(1 mark)

# %%
euro12 = Euro_2012_stats_TEAM
euro12.head(2)
# Out:
#              Team  Goals  Shots on target  Shots off target Shooting Accuracy  \
# 0         Croatia      4               13                12            51.90%
# 1  Czech Republic      4               13                18            41.90%
#
#   % Goals-to-shots  Total shots (inc. Blocked)  Hit Woodwork  Penalty goals  \
# 0           16.00%                          32             0              0
# 1           12.90%                          39             0              0
#
#    Penalties not scored  ...  Saves made  Saves-to-shots ratio  Fouls Won  \
# 0                     0  ...          13                81.30%         41
# 1                     0  ...           9                60.10%         53
#
#   Fouls Conceded  Offsides  Yellow Cards  Red Cards  Subs on  Subs off  \
# 0             62         2             9          0        9         9
# 1             73         8             7          0       11        11
#
#    Players Used
# 0            16
# 1            19
#
# [2 rows x 35 columns]

# %% [markdown]
# #### A. How many teams participated in the Euro2012 dataset.  (1 mark)

# %%
euro12.shape[0]
# Out:
# 469

# %% [markdown]
# #### B. Create a data frame with a name "discipline" consisting of (Team, Yellow Cards and Red Cards) .(1 mark)

# %%
discipline = euro12[['Team', 'Yellow Cards', 'Red Cards']]
discipline
# Out:
#                     Team  Yellow Cards  Red Cards
# 0                Croatia             9          0
# 1         Czech Republic             7          0
# 2                Denmark             4          0
# 3                England             5          0
# 4                 France             6          0
# 5                Germany             4          0
# 6                 Greece             9          1
# 7                  Italy            16          0
# 8            Netherlands             5          0
# 9                 Poland             7          1
# 10              Portugal            12          0
# 11   Republic of Ireland             6          1
# 12                Russia             6          0
# 13                 Spain            11          0
# 14                Sweden             7          0
# 15               Ukraine             5          0
# 16               Croatia             9          0
# 17        Czech Republic             7          0
# 18               Denmark             4          0
# 19               England             5          0
# 20                France             6          0
# 21               Germany             4          0
# 22                Greece             9          1
# 23                 Italy            16          0
# 24           Netherlands             5          0
# 25                Poland             7          1
# 26              Portugal            12          0
# 27   Republic of Ireland             6          1
# 28                Russia             6          0
# 29                 Spain            11          0
# ..                   ...           ...        ...
# 439                Italy            16          0
# 440          Netherlands             5          0
# 441               Poland             7          1
# 442             Portugal            12          0
# 443  Republic of Ireland             6          1
# 444               Russia             6          0
# 445                Spain            11          0
# 446               Sweden             7          0
# 447              Ukraine             5          0
# 448              Croatia             9          0
# 449       Czech Republic             7          0
# 450              Denmark             4          0
# 451              England             5          0
# 452               France             6          0
# 453              Germany             4          0
# 454               Greece             9          1
# 455                Italy            16          0
# 456          Netherlands             5          0
# 457               Poland             7          1
# 458             Portugal            12          0
# 459  Republic of Ireland             6          1
# 460               Russia             6          0
# 461                Spain            11          0
# 462               Sweden             7          0
# 463              Ukraine             5          0
# 464              Croatia             9          0
# 465       Czech Republic             7          0
# 466              Denmark             4          0
# 467              England             5          0
# 468               France             6          0
#
# [469 rows x 3 columns]

# %% [markdown]
# #### C. Find average Yellow Cards given per Team? (1 mark)

# %%
round(discipline['Yellow Cards'].mean())
# Out:
# 7

# %% [markdown]
# #### D. Find which teams  scored more than 6 goals(1 mark)

# %%
euro12[euro12.Goals > 6]
# Out:
#         Team  Goals  Shots on target  Shots off target Shooting Accuracy  \
# 5    Germany     10               32                32            47.80%
# 13     Spain     12               42                33            55.90%
# 21   Germany     10               32                32            47.80%
# 29     Spain     12               42                33            55.90%
# 37   Germany     10               32                32            47.80%
# 45     Spain     12               42                33            55.90%
# 53   Germany     10               32                32            47.80%
# 61     Spain     12               42                33            55.90%
# 69   Germany     10               32                32            47.80%
# 77     Spain     12               42                33            55.90%
# 85   Germany     10               32                32            47.80%
# 93     Spain     12               42                33            55.90%
# 101  Germany     10               32                32            47.80%
# 109    Spain     12               42                33            55.90%
# 117  Germany     10               32                32            47.80%
# 125    Spain     12               42                33            55.90%
# 133  Germany     10               32                32            47.80%
# 141    Spain     12               42                33            55.90%
# 149  Germany     10               32                32            47.80%
# 157    Spain     12               42                33            55.90%
# 165  Germany     10               32                32            47.80%
# 173    Spain     12               42                33            55.90%
# 181  Germany     10               32                32            47.80%
# 189    Spain     12               42                33            55.90%
# 197  Germany     10               32                32            47.80%
# 205    Spain     12               42                33            55.90%
# 213  Germany     10               32                32            47.80%
# 221    Spain     12               42                33            55.90%
# 229  Germany     10               32                32            47.80%
# 237    Spain     12               42                33            55.90%
# 245  Germany     10               32                32            47.80%
# 253    Spain     12               42                33            55.90%
# 261  Germany     10               32                32            47.80%
# 269    Spain     12               42                33            55.90%
# 277  Germany     10               32                32            47.80%
# 285    Spain     12               42                33            55.90%
# 293  Germany     10               32                32            47.80%
# 301    Spain     12               42                33            55.90%
# 309  Germany     10               32                32            47.80%
# 317    Spain     12               42                33            55.90%
# 325  Germany     10               32                32            47.80%
# 333    Spain     12               42                33            55.90%
# 341  Germany     10               32                32            47.80%
# 349    Spain     12               42                33            55.90%
# 357  Germany     10               32                32            47.80%
# 365    Spain     12               42                33            55.90%
# 373  Germany     10               32                32            47.80%
# 381    Spain     12               42                33            55.90%
# 389  Germany     10               32                32            47.80%
# 397    Spain     12               42                33            55.90%
# 405  Germany     10               32                32            47.80%
# 413    Spain     12               42                33            55.90%
# 421  Germany     10               32                32            47.80%
# 429    Spain     12               42                33            55.90%
# 437  Germany     10               32                32            47.80%
# 445    Spain     12               42                33            55.90%
# 453  Germany     10               32                32            47.80%
# 461    Spain     12               42                33            55.90%
#
#     % Goals-to-shots  Total shots (inc. Blocked)  Hit Woodwork  Penalty goals  \
# 5             15.60%                          80             2              1
# 13            16.00%                         100             0              1
# 21            15.60%                          80             2              1
# 29            16.00%                         100             0              1
# 37            15.60%                          80             2              1
# 45            16.00%                         100             0              1
# 53            15.60%                          80             2              1
# 61            16.00%                         100             0              1
# 69            15.60%                          80             2              1
# 77            16.00%                         100             0              1
# 85            15.60%                          80             2              1
# 93            16.00%                         100             0              1
# 101           15.60%                          80             2              1
# 109           16.00%                         100             0              1
# 117           15.60%                          80             2              1
# 125           16.00%                         100             0              1
# 133           15.60%                          80             2              1
# 141           16.00%                         100             0              1
# 149           15.60%                          80             2              1
# 157           16.00%                         100             0              1
# 165           15.60%                          80             2              1
# 173           16.00%                         100             0              1
# 181           15.60%                          80             2              1
# 189           16.00%                         100             0              1
# 197           15.60%                          80             2              1
# 205           16.00%                         100             0              1
# 213           15.60%                          80             2              1
# 221           16.00%                         100             0              1
# 229           15.60%                          80             2              1
# 237           16.00%                         100             0              1
# 245           15.60%                          80             2              1
# 253           16.00%                         100             0              1
# 261           15.60%                          80             2              1
# 269           16.00%                         100             0              1
# 277           15.60%                          80             2              1
# 285           16.00%                         100             0              1
# 293           15.60%                          80             2              1
# 301           16.00%                         100             0              1
# 309           15.60%                          80             2              1
# 317           16.00%                         100             0              1
# 325           15.60%                          80             2              1
# 333           16.00%                         100             0              1
# 341           15.60%                          80             2              1
# 349           16.00%                         100             0              1
# 357           15.60%                          80             2              1
# 365           16.00%                         100             0              1
# 373           15.60%                          80             2              1
# 381           16.00%                         100             0              1
# 389           15.60%                          80             2              1
# 397           16.00%                         100             0              1
# 405           15.60%                          80             2              1
# 413           16.00%                         100             0              1
# 421           15.60%                          80             2              1
# 429           16.00%                         100             0              1
# 437           15.60%                          80             2              1
# 445           16.00%                         100             0              1
# 453           15.60%                          80             2              1
# 461           16.00%                         100             0              1
#
#      Penalties not scored  ...  Saves made  Saves-to-shots ratio  Fouls Won  \
# 5                       0  ...          10                62.60%         63
# 13                      0  ...          15                93.80%        102
# 21                      0  ...          10                62.60%         63
# 29                      0  ...          15                93.80%        102
# 37                      0  ...          10                62.60%         63
# 45                      0  ...          15                93.80%        102
# 53                      0  ...          10                62.60%         63
# 61                      0  ...          15                93.80%        102
# 69                      0  ...          10                62.60%         63
# 77                      0  ...          15                93.80%        102
# 85                      0  ...          10                62.60%         63
# 93                      0  ...          15                93.80%        102
# 101                     0  ...          10                62.60%         63
# 109                     0  ...          15                93.80%        102
# 117                     0  ...          10                62.60%         63
# 125                     0  ...          15                93.80%        102
# 133                     0  ...          10                62.60%         63
# 141                     0  ...          15                93.80%        102
# 149                     0  ...          10                62.60%         63
# 157                     0  ...          15                93.80%        102
# 165                     0  ...          10                62.60%         63
# 173                     0  ...          15                93.80%        102
# 181                     0  ...          10                62.60%         63
# 189                     0  ...          15                93.80%        102
# 197                     0  ...          10                62.60%         63
# 205                     0  ...          15                93.80%        102
# 213                     0  ...          10                62.60%         63
# 221                     0  ...          15                93.80%        102
# 229                     0  ...          10                62.60%         63
# 237                     0  ...          15                93.80%        102
# 245                     0  ...          10                62.60%         63
# 253                     0  ...          15                93.80%        102
# 261                     0  ...          10                62.60%         63
# 269                     0  ...          15                93.80%        102
# 277                     0  ...          10                62.60%         63
# 285                     0  ...          15                93.80%        102
# 293                     0  ...          10                62.60%         63
# 301                     0  ...          15                93.80%        102
# 309                     0  ...          10                62.60%         63
# 317                     0  ...          15                93.80%        102
# 325                     0  ...          10                62.60%         63
# 333                     0  ...          15                93.80%        102
# 341                     0  ...          10                62.60%         63
# 349                     0  ...          15                93.80%        102
# 357                     0  ...          10                62.60%         63
# 365                     0  ...          15                93.80%        102
# 373                     0  ...          10                62.60%         63
# 381                     0  ...          15                93.80%        102
# 389                     0  ...          10                62.60%         63
# 397                     0  ...          15                93.80%        102
# 405                     0  ...          10                62.60%         63
# 413                     0  ...          15                93.80%        102
# 421                     0  ...          10                62.60%         63
# 429                     0  ...          15                93.80%        102
# 437                     0  ...          10                62.60%         63
# 445                     0  ...          15                93.80%        102
# 453                     0  ...          10                62.60%         63
# 461                     0  ...          15                93.80%        102
#
#     Fouls Conceded  Offsides  Yellow Cards  Red Cards  Subs on  Subs off  \
# 5               49        12             4          0       15        15
# 13              83        19            11          0       17        17
# 21              49        12             4          0       15        15
# 29              83        19            11          0       17        17
# 37              49        12             4          0       15        15
# 45              83        19            11          0       17        17
# 53              49        12             4          0       15        15
# 61              83        19            11          0       17        17
# 69              49        12             4          0       15        15
# 77              83        19            11          0       17        17
# 85              49        12             4          0       15        15
# 93              83        19            11          0       17        17
# 101             49        12             4          0       15        15
# 109             83        19            11          0       17        17
# 117             49        12             4          0       15        15
# 125             83        19            11          0       17        17
# 133             49        12             4          0       15        15
# 141             83        19            11          0       17        17
# 149             49        12             4          0       15        15
# 157             83        19            11          0       17        17
# 165             49        12             4          0       15        15
# 173             83        19            11          0       17        17
# 181             49        12             4          0       15        15
# 189             83        19            11          0       17        17
# 197             49        12             4          0       15        15
# 205             83        19            11          0       17        17
# 213             49        12             4          0       15        15
# 221             83        19            11          0       17        17
# 229             49        12             4          0       15        15
# 237             83        19            11          0       17        17
# 245             49        12             4          0       15        15
# 253             83        19            11          0       17        17
# 261             49        12             4          0       15        15
# 269             83        19            11          0       17        17
# 277             49        12             4          0       15        15
# 285             83        19            11          0       17        17
# 293             49        12             4          0       15        15
# 301             83        19            11          0       17        17
# 309             49        12             4          0       15        15
# 317             83        19            11          0       17        17
# 325             49        12             4          0       15        15
# 333             83        19            11          0       17        17
# 341             49        12             4          0       15        15
# 349             83        19            11          0       17        17
# 357             49        12             4          0       15        15
# 365             83        19            11          0       17        17
# 373             49        12             4          0       15        15
# 381             83        19            11          0       17        17
# 389             49        12             4          0       15        15
# 397             83        19            11          0       17        17
# 405             49        12             4          0       15        15
# 413             83        19            11          0       17        17
# 421             49        12             4          0       15        15
# 429             83        19            11          0       17        17
# 437             49        12             4          0       15        15
# 445             83        19            11          0       17        17
# 453             49        12             4          0       15        15
# 461             83        19            11          0       17        17
#
#      Players Used
# 5              17
# 13             18
# 21             17
# 29             18
# 37             17
# 45             18
# 53             17
# 61             18
# 69             17
# 77             18
# 85             17
# 93             18
# 101            17
# 109            18
# 117            17
# 125            18
# 133            17
# 141            18
# 149            17
# 157            18
# 165            17
# 173            18
# 181            17
# 189            18
# 197            17
# 205            18
# 213            17
# 221            18
# 229            17
# 237            18
# 245            17
# 253            18
# 261            17
# 269            18
# 277            17
# 285            18
# 293            17
# 301            18
# 309            17
# 317            18
# 325            17
# 333            18
# 341            17
# 349            18
# 357            17
# 365            18
# 373            17
# 381            18
# 389            17
# 397            18
# 405            17
# 413            18
# 421            17
# 429            18
# 437            17
# 445            18
# 453            17
# 461            18
#
# [58 rows x 35 columns]

# %% [markdown]
# #### E. Display the teams start with G (1 mark)

# %%
euro12[euro12.Team.str.startswith('G')].head()
# Out:
#        Team  Goals  Shots on target  Shots off target Shooting Accuracy  \
# 5   Germany     10               32                32            47.80%
# 6    Greece      5                8                18            30.70%
# 21  Germany     10               32                32            47.80%
# 22   Greece      5                8                18            30.70%
# 37  Germany     10               32                32            47.80%
#
#    % Goals-to-shots  Total shots (inc. Blocked)  Hit Woodwork  Penalty goals  \
# 5            15.60%                          80             2              1
# 6            19.20%                          32             1              1
# 21           15.60%                          80             2              1
# 22           19.20%                          32             1              1
# 37           15.60%                          80             2              1
#
#     Penalties not scored  ...  Saves made  Saves-to-shots ratio  Fouls Won  \
# 5                      0  ...          10                62.60%         63
# 6                      1  ...          13                65.10%         67
# 21                     0  ...          10                62.60%         63
# 22                     1  ...          13                65.10%         67
# 37                     0  ...          10                62.60%         63
#
#    Fouls Conceded  Offsides  Yellow Cards  Red Cards  Subs on  Subs off  \
# 5              49        12             4          0       15        15
# 6              48        12             9          1       12        12
# 21             49        12             4          0       15        15
# 22             48        12             9          1       12        12
# 37             49        12             4          0       15        15
#
#     Players Used
# 5             17
# 6             20
# 21            17
# 22            20
# 37            17
#
# [5 rows x 35 columns]

# %% [markdown]
# ### 4.Read the dataset ( hotdog)
#
# A. Give Column names as Type, Calories, Sodium? (1 Mark)
#
# B. Find out average Calories and average Sodium vales for each Hotdog type (1 Mark)
#
# C. Find out rows having Calories less than 120 and Sodium values greater than 300 (1 Marks)
#
# D. Create Column Grade having values 'A' and 'B' as follows:
#
# Grade A:  Items having Calorie value less than 150 and Sodium value less than 400
#
# Grade B:   Otherwise (2 Marks)

# %% [markdown]
# #### A. Give Column names as Type, Calories, Sodium? (1 Mark)

# %%
hotdogs = hotdogs
hotdogs.head()
# Out:
#    Beef  186  495
# 0  Beef  181  477
# 1  Beef  176  425
# 2  Beef  149  322
# 3  Beef  184  482
# 4  Beef  190  587

# %%
hotdogs.columns = ['Type','Calories','Sodium']
hotdogs.head()
# Out:
#    Type  Calories  Sodium
# 0  Beef       181     477
# 1  Beef       176     425
# 2  Beef       149     322
# 3  Beef       184     482
# 4  Beef       190     587

# %% [markdown]
# #### B. Find out average Calories and average Sodium vales for each Hotdog type (1 Mark)

# %%
hotdog_gr=hotdogs.groupby(['Type']).mean()
hotdog_gr
# Out:
#            Calories      Sodium
# Type
# Beef     155.915254  397.824859
# Meat     158.705882  418.529412
# Poultry  118.812950  457.733813

# %% [markdown]
# #### C. Find out rows having Calories less than 120 and Sodium values greater than 300 (1 Marks)

# %%
hotdogs[ ( hotdogs['Calories']< 120) & (hotdogs['Sodium'] > 300 )]
# Out:
#         Type  Calories  Sodium
# 38   Poultry       102     396
# 39   Poultry       106     383
# 40   Poultry        94     387
# 41   Poultry       102     542
# 42   Poultry        87     359
# 43   Poultry        99     357
# 44   Poultry       107     528
# 45   Poultry       113     513
# 48   Poultry        86     358
# 91   Poultry       102     396
# 92   Poultry       106     383
# 93   Poultry        94     387
# 94   Poultry       102     542
# 95   Poultry        87     359
# 96   Poultry        99     357
# 97   Poultry       107     528
# 98   Poultry       113     513
# 101  Poultry        86     358
# 144  Poultry       102     396
# 145  Poultry       106     383
# 146  Poultry        94     387
# 147  Poultry       102     542
# 148  Poultry        87     359
# 149  Poultry        99     357
# 150  Poultry       107     528
# 151  Poultry       113     513
# 154  Poultry        86     358
# 197  Poultry       102     396
# 198  Poultry       106     383
# 199  Poultry        94     387
# ..       ...       ...     ...
# 257  Poultry       113     513
# 260  Poultry        86     358
# 303  Poultry       102     396
# 342  Poultry       102     396
# 343  Poultry       106     383
# 344  Poultry        94     387
# 345  Poultry       102     542
# 346  Poultry        87     359
# 347  Poultry        99     357
# 348  Poultry       107     528
# 349  Poultry       113     513
# 352  Poultry        86     358
# 395  Poultry       102     396
# 396  Poultry       106     383
# 397  Poultry        94     387
# 398  Poultry       102     542
# 399  Poultry        87     359
# 400  Poultry        99     357
# 401  Poultry       107     528
# 402  Poultry       113     513
# 405  Poultry        86     358
# 448  Poultry       102     396
# 449  Poultry       106     383
# 450  Poultry        94     387
# 451  Poultry       102     542
# 452  Poultry        87     359
# 453  Poultry        99     357
# 454  Poultry       107     528
# 455  Poultry       113     513
# 458  Poultry        86     358
#
# [73 rows x 3 columns]

# %% [markdown]
# #### D. Create Column Grade having values 'A' and 'B' as follows:
# <br>  Grade A :  Items having Calorie value less than 150 and Sodium value less than 400
# <br>  Grade B:   Otherwise

# %%
def fun(x):
    if (x.Calories < 150) & (x.Sodium < 400):
        return 'A'
    else:
        return 'B'

hotdogs['Grade'] = hotdogs.apply(fun,axis=1)
hotdogs.head(10)
# Out:
#    Type  Calories  Sodium Grade
# 0  Beef       181     477     B
# 1  Beef       176     425     B
# 2  Beef       149     322     A
# 3  Beef       184     482     B
# 4  Beef       190     587     B
# 5  Beef       158     370     B
# 6  Beef       139     322     A
# 7  Beef       175     479     B
# 8  Beef       148     375     A
# 9  Beef       152     330     B

# %% [markdown]
# --------------

# %% [markdown]
# # SECTION B: 20 MARKS

# %% [markdown]
# ----------

# %% [markdown]
# ### 5. Read the dataset (stock_data)
#
# A. Give column names as `timestamp`, `AA`, `AAPL`, `GE`, `IBM`, `JNJ`, `MSFT`, `PEP`, `SPX`, `XOM`. List all the columns of the dataset, Identify the numerical, categorical columns. (4 Marks)
#
# B. Convert the column `timestamp` into python datetime object (1 Marks)
#
# C. Find Average value of stock `AAPL` in the year 2009  (5 Marks)

# %% [markdown]
# #### A. Give colum names as `timestamp`, `AA`,`AAPL`,`GE`,`IBM`,`JNJ`,`MSFT`,`PEP`,`SPX`,`XOM` . List all the columns of dataset, Identify the numerical, categorical columns.(4 Marks)

# %%
stocks=stock_data
stocks.rename( columns={'Unnamed: 48':'timestamp'}, inplace=True )
stocks.head(2)
# Out:
#           timestamp     AA    AAPL     GE     IBM    JNJ   MSFT    PEP  \
# 0  29-10-2007 00:00  37.41  185.09  34.46  106.78  57.13  31.78  65.67
# 1  30-10-2007 00:00  36.43  187.00  34.39  106.15  56.99  32.70  65.80
#
#        SPX    XOM
# 0  1540.98  85.51
# 1  1531.02  83.25

# %%
stocks.columns
# Out:
# Index(['timestamp', 'AA', 'AAPL', 'GE', 'IBM', 'JNJ', 'MSFT', 'PEP', 'SPX',
#        'XOM'],
#       dtype='object')

# %% [markdown]
# #### B. Convert the column `timestamp` into python datetime object (1 Marks)

# %%
stocks['timestamp']=pd.to_datetime(stocks['timestamp'])

# %%
stocks.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 469 entries, 0 to 468
# Data columns (total 10 columns):
# timestamp    469 non-null datetime64[ns]
# AA           469 non-null float64
# AAPL         469 non-null float64
# GE           469 non-null float64
# IBM          469 non-null float64
# JNJ          469 non-null float64
# MSFT         469 non-null float64
# PEP          469 non-null float64
# SPX          469 non-null float64
# XOM          469 non-null float64
# dtypes: datetime64[ns](1), float64(9)
# memory usage: 36.7 KB

# %% [markdown]
# #### C.  Find Average value of stock `AAPL` in year 2009  (5 Marks)

# %%
stocks_year=stocks.groupby(stocks.timestamp.dt.year)
yearwise_mean=stocks_year.mean()
#print(yearwise_mean)
yearwise_mean.loc[2009]['AAPL']
# Out:
# 124.87337209302326

# %% [markdown]
# ### 6. Read the dataset(Report_2010_to_Congress_on_White_House_Staff) and Answer the below questions?
#
# **Exercise:1** Find the position title to which more amount is spent on salaries? (6 marks)
#
# **Exercise:2**
#
# 2A. Find the position title to which the least amount is spent on salaries? (2 marks)
#
# 2B) Find the highest-paid position title? (2 marks)
#
# **Exercise:3**
#
# 3.A)Find the least paid position title? (1 marks)
#
# 3.B) Find the percentage of the amount spent on each position w.r.t Salaries? (3 marks)

# %%
data=Report_2010_to_Congress_on_White_House_Staff

# %% [markdown]
# #### **Exercise:1** Find the position title to which more amount is spent on salaries? (6 marks)

# %%
# Firstly ,group the employees based on position title
df_bypositiontitle=data.groupby('Position Title')

# After grouping ,perform sum operation on salary to get the total amount spent on each position title
df_bypositiontitle['Salary'].sum()

# If we want the result to be sorted in descending order then 
df_bypositiontitle['Salary'].sum().sort_values(ascending=False)

# Result represented in dataframe
pd.DataFrame(df_bypositiontitle['Salary'].sum().sort_values(ascending=False))

# Position Title to which more Amount is spent
df_positiontitle=pd.DataFrame(df_bypositiontitle['Salary'].sum().sort_values(ascending=False))
df_positiontitle.iloc[0]
# Out:
# Salary    1305000
# Name: SPECIAL ASSISTANT TO THE PRESIDENT FOR LEGISLATIVE AFFAIRS, dtype: int64

# %% [markdown]
# ### **Exercise:2**
#
# #### 2A. Find the position title to which the least amount is spent on salaries? (2 marks)

# %%
# case 2 : Find the position title to which least amount is spent on salaries
df_positiontitle_asc=pd.DataFrame(df_bypositiontitle['Salary'].sum().sort_values(ascending=True))
df_positiontitle_asc.iloc[0]
# Out:
# Salary    42000
# Name: ADVANCE COORDINATOR, dtype: int64

# %% [markdown]
# #### 2B) Find the highest-paid position title? (2 marks)

# %%
df_case3=pd.DataFrame(df_bypositiontitle['Salary'].max().sort_values(ascending=False))
df_case3
# Out:
#                                                     Salary
# Position Title
# DEPUTY DIRECTOR                                     179700
# POLICY DIRECTOR                                     179700
# ASSISTANT TO THE PRESIDENT FOR ENERGY AND CLIMA...  172200
# ASSISTANT TO THE PRESIDENT AND DIRECTOR OF COMM...  172200
# ASSISTANT TO THE PRESIDENT FOR HOMELAND SECURIT...  172200
# ASSISTANT TO THE PRESIDENT AND DIRECTOR, OFFICE...  172200
# ASSISTANT TO THE PRESIDENT FOR SPECIAL PROJECTS     172200
# ASSISTANT TO THE PRESIDENT AND PRESS SECRETARY      172200
# ASSISTANT TO THE PRESIDENT, CHIEF OF STAFF TO T...  172200
# ASSISTANT TO THE PRESIDENT AND DIRECTOR OF SPEE...  172200
# ASSISTANT TO THE PRESIDENT AND DIRECTOR OF THE ...  172200
# ASSISTANT TO THE PRESIDENT AND DIRECTOR OF POLI...  172200
# ASSISTANT TO THE PRESIDENT AND DIRECTOR OF SCHE...  172200
# ASSISTANT TO THE PRESIDENT AND DEPUTY NATIONAL ...  172200
# ASSISTANT TO THE PRESIDENT AND CHIEF OF STAFF       172200
# NATIONAL SECURITY ADVISOR                           172200
# ASSISTANT TO THE PRESIDENT FOR ECONOMIC POLICY ...  172200
# ASSISTANT TO THE PRESIDENT AND CABINET SECRETARY    172200
# ASSISTANT TO THE PRESIDENT AND STAFF SECRETARY      172200
# ASSISTANT TO THE PRESIDENT AND DEPUTY CHIEF OF ...  172200
# SENIOR ADVISOR AND ASSISTANT TO THE PRESIDENT F...  172200
# ASSISTANT TO THE PRESIDENT AND COUNSEL TO THE P...  172200
# ASSISTANT TO THE PRESIDENT AND SENIOR ADVISOR       172200
# ASSISTANT TO THE PRESIDENT AND DEPUTY CHIEF OF ...  172200
# SENIOR ADVISOR FOR TECHNOLOGY AND INNOVATION TO...  172000
# SENIOR POLICY DIRECTOR                              165000
# ASSISTANT TO THE PRESIDENT FOR MANAGEMENT AND A...  162900
# DEPUTY ASSISTANT TO THE PRESIDENT AND SENIOR AD...  162500
# DEPUTY ASSISTANT TO THE PRESIDENT AND DEPUTY CO...  158500
# DEPUTY ASSISTANT TO THE PRESIDENT AND DEPUTY ST...  158500
# ...                                                    ...
# EXECUTIVE ASSISTANT TO THE POLITICAL DIRECTOR        45000
# EXECUTIVE ASSISTANT TO THE DIRECTOR OF SCHEDULI...   45000
# EXECUTIVE ASSISTANT TO THE DIRECTOR OF PUBLIC E...   45000
# EXECUTIVE ASSISTANT TO THE CHIEF OF STAFF TO TH...   45000
# ASSOCIATE DIRECTOR OF PRESS ADVANCE                  45000
# DEPUTY DIRECTOR FOR BROADCAST MEDIA                  45000
# DEPUTY DIRECTOR OF RESPONSE                          45000
# SCHEDULER FOR CHIEF OF STAFF                         45000
# SPECIAL ASSISTANT TO THE CABINET SECRETARY           45000
# COORDINATOR                                          45000
# SPECIAL SERVICES OPERATOR                            43860
# OPERATOR                                             43656
# STAFF ASSISTANT                                      42840
# DEPUTY ASSOCIATE DIRECTOR OF CORRESPONDENCE FOR...   42000
# LEGISLATIVE ASSISTANT AND ASSISTANT TO THE HOUS...   42000
# BOARDS AND COMMISSIONS STAFF ASSISTANT               42000
# LEGISLATIVE ASSISTANT                                42000
# WEST WING RECEPTIONIST                               42000
# SENIOR ANALYST                                       42000
# ASSISTANT SPEECHWRITER                               42000
# MEDIA MONITOR                                        42000
# RESEARCH ASSOCIATE                                   42000
# ENERGY AND ENVIRONMENT STAFF ASSISTANT               42000
# ECONOMICS STAFF ASSISTANT                            42000
# DOMESTIC STAFF ASSISTANT                             42000
# NATIONAL SECURITY STAFF ASSISTANT                    42000
# PRIORITY PLACEMENT STAFF ASSISTANT                   42000
# OPERATIONS STAFF ASSISTANT                           42000
# PRESS ASSISTANT                                      42000
# ADVANCE COORDINATOR                                  42000
#
# [269 rows x 1 columns]

# %% [markdown]
# #### **Exercise:3**
#
# #### 3.A)Find the least paid position title? (1 mark)

# %%
#case : Find the least paid position title
df_bypositiontitle['Salary'].max().sort_values(ascending=True)
# Out:
# Position Title
# ADVANCE COORDINATOR                                                                                   42000
# PRESS ASSISTANT                                                                                       42000
# OPERATIONS STAFF ASSISTANT                                                                            42000
# PRIORITY PLACEMENT STAFF ASSISTANT                                                                    42000
# NATIONAL SECURITY STAFF ASSISTANT                                                                     42000
# DOMESTIC STAFF ASSISTANT                                                                              42000
# ECONOMICS STAFF ASSISTANT                                                                             42000
# ENERGY AND ENVIRONMENT STAFF ASSISTANT                                                                42000
# RESEARCH ASSOCIATE                                                                                    42000
# MEDIA MONITOR                                                                                         42000
# ASSISTANT SPEECHWRITER                                                                                42000
# SENIOR ANALYST                                                                                        42000
# WEST WING RECEPTIONIST                                                                                42000
# LEGISLATIVE ASSISTANT                                                                                 42000
# BOARDS AND COMMISSIONS STAFF ASSISTANT                                                                42000
# LEGISLATIVE ASSISTANT AND ASSISTANT TO THE HOUSE LIAISON                                              42000
# DEPUTY ASSOCIATE DIRECTOR OF CORRESPONDENCE FOR THE FIRST LADY                                        42000
# STAFF ASSISTANT                                                                                       42840
# OPERATOR                                                                                              43656
# SPECIAL SERVICES OPERATOR                                                                             43860
# COORDINATOR                                                                                           45000
# SPECIAL ASSISTANT TO THE CABINET SECRETARY                                                            45000
# SCHEDULER FOR CHIEF OF STAFF                                                                          45000
# DEPUTY DIRECTOR OF RESPONSE                                                                           45000
# DEPUTY DIRECTOR FOR BROADCAST MEDIA                                                                   45000
# ASSOCIATE DIRECTOR OF PRESS ADVANCE                                                                   45000
# EXECUTIVE ASSISTANT TO THE CHIEF OF STAFF TO THE FIRST LADY                                           45000
# EXECUTIVE ASSISTANT TO THE DIRECTOR OF PUBLIC ENGAGEMENT                                              45000
# EXECUTIVE ASSISTANT TO THE DIRECTOR OF SCHEDULING AND ADVANCE                                         45000
# EXECUTIVE ASSISTANT TO THE POLITICAL DIRECTOR                                                         45000
#                                                                                                       ...
# DEPUTY ASSISTANT TO THE PRESIDENT AND DEPUTY STAFF SECRETARY                                         158500
# DEPUTY ASSISTANT TO THE PRESIDENT AND DEPUTY COUNSEL TO THE PRESIDENT                                158500
# DEPUTY ASSISTANT TO THE PRESIDENT AND SENIOR ADVISOR TO THE CHIEF OF STAFF                           162500
# ASSISTANT TO THE PRESIDENT FOR MANAGEMENT AND ADMINISTRATION                                         162900
# SENIOR POLICY DIRECTOR                                                                               165000
# SENIOR ADVISOR FOR TECHNOLOGY AND INNOVATION TO THE NATIONAL ECONOMIC COUNCIL DIRECTOR               172000
# ASSISTANT TO THE PRESIDENT AND DEPUTY CHIEF OF STAFF FOR OPERATIONS                                  172200
# ASSISTANT TO THE PRESIDENT AND SENIOR ADVISOR                                                        172200
# ASSISTANT TO THE PRESIDENT AND COUNSEL TO THE PRESIDENT                                              172200
# SENIOR ADVISOR AND ASSISTANT TO THE PRESIDENT FOR INTERGOVERNMENTAL AFFAIRS AND PUBLIC ENGAGEMENT    172200
# ASSISTANT TO THE PRESIDENT AND DEPUTY CHIEF OF STAFF FOR POLICY                                      172200
# ASSISTANT TO THE PRESIDENT AND STAFF SECRETARY                                                       172200
# ASSISTANT TO THE PRESIDENT AND CABINET SECRETARY                                                     172200
# ASSISTANT TO THE PRESIDENT FOR ECONOMIC POLICY AND DIRECTOR OF THE NATIONAL ECONOMIC COUNCIL         172200
# NATIONAL SECURITY ADVISOR                                                                            172200
# ASSISTANT TO THE PRESIDENT AND CHIEF OF STAFF                                                        172200
# ASSISTANT TO THE PRESIDENT AND DEPUTY NATIONAL SECURITY ADVISOR                                      172200
# ASSISTANT TO THE PRESIDENT AND DIRECTOR OF SCHEDULING AND ADVANCE                                    172200
# ASSISTANT TO THE PRESIDENT AND DIRECTOR OF POLITICAL AFFAIRS                                         172200
# ASSISTANT TO THE PRESIDENT AND DIRECTOR OF THE DOMESTIC POLICY COUNCIL                               172200
# ASSISTANT TO THE PRESIDENT AND DIRECTOR OF SPEECHWRITING                                             172200
# ASSISTANT TO THE PRESIDENT, CHIEF OF STAFF TO THE FIRST LADY AND COUNSEL                             172200
# ASSISTANT TO THE PRESIDENT AND PRESS SECRETARY                                                       172200
# ASSISTANT TO THE PRESIDENT FOR SPECIAL PROJECTS                                                      172200
# ASSISTANT TO THE PRESIDENT AND DIRECTOR, OFFICE OF LEGISLATIVE AFFAIRS                               172200
# ASSISTANT TO THE PRESIDENT FOR HOMELAND SECURITY AND COUNTERTERRORISM                                172200
# ASSISTANT TO THE PRESIDENT AND DIRECTOR OF COMMUNICATIONS                                            172200
# ASSISTANT TO THE PRESIDENT FOR ENERGY AND CLIMATE CHANGE                                             172200
# POLICY DIRECTOR                                                                                      179700
# DEPUTY DIRECTOR                                                                                      179700
# Name: Salary, Length: 269, dtype: int64

# %% [markdown]
# #### 3.B) Find the percentage of the amount spent on each position w.r.t Salaries? (3 marks)

# %%
s=sum(data['Salary'])
df_case7=pd.DataFrame(df_bypositiontitle['Salary'].sum().sort_values(ascending=False))
result =(df_case7/s)*100 
result
# Out:
#                                                       Salary
# Position Title
# SPECIAL ASSISTANT TO THE PRESIDENT FOR LEGISLAT...  3.363722
# SPECIAL ASSISTANT TO THE PRESIDENT AND ASSOCIAT...  3.321192
# STAFF ASSISTANT                                     2.546222
# RECORDS MANAGEMENT ANALYST                          2.050891
# DEPUTY ASSOCIATE COUNSEL FOR PRESIDENTIAL PERSO...  1.691426
# POLICY ADVISOR                                      1.658178
# DEPUTY ASSISTANT TO THE PRESIDENT AND DEPUTY CO...  1.634176
# ASSOCIATE DIRECTOR                                  1.542031
# ETHICS ADVISOR                                      1.266038
# ANALYST                                             1.251132
# SPECIAL ASSISTANT TO THE PRESIDENT AND SPECIAL ...  1.081288
# SPECIAL ASSISTANT                                   1.019494
# ASSISTANT PRESS SECRETARY                           1.005250
# ASSISTANT DIRECTOR                                  0.946740
# ASSISTANT TO THE PRESIDENT AND SENIOR ADVISOR       0.887713
# ASSISTANT SHIFT LEADER                              0.885468
# SENIOR ANALYST                                      0.866062
# SPECIAL ASSISTANT TO THE PRESIDENT FOR PRESIDEN...  0.845441
# DEPUTY DIRECTOR                                     0.824048
# DEPUTY ASSOCIATE COUNSEL                            0.765537
# DEPUTY ASSOCIATE DIRECTOR                           0.758147
# RESEARCHER                                          0.719672
# SENIOR POLICY ADVISOR                               0.682774
# SPECIAL ASSISTANT TO THE PRESIDENT FOR ECONOMIC...  0.672744
# DEPUTY DIRECTOR OF CABINET AFFAIRS                  0.631503
# ASSISTANT STAFF SECRETARY                           0.618616
# PRIORITY PLACEMENT DIRECTOR                         0.590469
# SPECIAL ASSISTANT TO THE PRESIDENT AND DEPUTY P...  0.582530
# SPECIAL ASSISTANT AND ADVANCE LEAD                  0.575570
# ASSISTANT EXECUTIVE CLERK                           0.527821
# ...                                                      ...
# EXECUTIVE ASSISTANT TO THE EXECUTIVE DIRECTOR       0.118310
# LEGISLATIVE ASSISTANT AND ASSISTANT FOR EVENTS      0.115990
# EXECUTIVE ASSISTANT TO THE CHIEF OF STAFF TO TH...  0.115990
# DEPUTY DIRECTOR FOR BROADCAST MEDIA                 0.115990
# DEPUTY DIRECTOR OF RESPONSE                         0.115990
# ASSOCIATE DIRECTOR OF PRESS ADVANCE                 0.115990
# EXECUTIVE ASSISTANT TO THE POLITICAL DIRECTOR       0.115990
# SCHEDULER FOR CHIEF OF STAFF                        0.115990
# LEGISLATIVE ASSISTANT AND ASSOCIATE DIRECTOR FO...  0.115990
# ASSOCIATE DIRECTOR FOR SCHEDULING CORRESPONDENCE    0.115990
# EXECUTIVE ASSISTANT TO THE DIRECTOR OF PUBLIC E...  0.115990
# LEGISLATIVE ASSISTANT AND ASSISTANT TO THE SENA...  0.115990
# EXECUTIVE ASSISTANT TO THE DIRECTOR OF SCHEDULI...  0.115990
# SPECIAL ASSISTANT TO THE CHIEF OF STAFF OF THE ...  0.115990
# SPECIAL ASSISTANT TO THE CABINET SECRETARY          0.115990
# LEGISLATIVE ASSISTANT AND ASSISTANT TO THE DIRE...  0.115990
# ASSISTANT SPEECHWRITER                              0.108258
# PRIORITY PLACEMENT STAFF ASSISTANT                  0.108258
# BOARDS AND COMMISSIONS STAFF ASSISTANT              0.108258
# OPERATIONS STAFF ASSISTANT                          0.108258
# WEST WING RECEPTIONIST                              0.108258
# DOMESTIC STAFF ASSISTANT                            0.108258
# DEPUTY ASSOCIATE DIRECTOR OF CORRESPONDENCE FOR...  0.108258
# NATIONAL SECURITY STAFF ASSISTANT                   0.108258
# MEDIA MONITOR                                       0.108258
# RESEARCH ASSOCIATE                                  0.108258
# ECONOMICS STAFF ASSISTANT                           0.108258
# ENERGY AND ENVIRONMENT STAFF ASSISTANT              0.108258
# LEGISLATIVE ASSISTANT AND ASSISTANT TO THE HOUS...  0.108258
# ADVANCE COORDINATOR                                 0.108258
#
# [269 rows x 1 columns]

# %% [markdown]
# ------------------
# # SECTION C: 30 MARKS
#
# ------------------

# %% [markdown]
# ### 7. Read the dataset(Fifa) and Answer the below questions?

# %%
Fifa = Fifa

# %% [markdown]
# ### 7A).	Data Manipulation for Value Column (5 Marks).
#
# **Step1:** Clean Value column by removing '?' from each row.
#
# **Step2:** Convert the column in uniform unit i.e. 'K' by using given conversion rate 1 =1000 K and also remove the letter 'K' and 'M' from each row.
#
# **Step3:** Convert the Datatype of the column to 'float'
#
# **First 5 values of Sample output column should look like this:**
#
#
# |0   |    750.0|
# |----|-------|
# |1   |   21500.0|
# |2    |   4000.0|
# |3    |   240.0|
# |4    |   150.0|
#
# Name: Value, dtype: float64

# %%
def convert_curr(value):
    value=value.replace('?','')
   
    value=value.replace('K','')
   
    if 'M' in value:
        value=value.replace('M','')
        value=str(float(value)*1000)
    
    return value
    
Fifa['Value']=Fifa['Value'].apply(convert_curr)
Fifa['Value']=Fifa['Value'].astype('float')
Fifa.Value.head()
# Out:
# 0      750.0
# 1    21500.0
# 2     4000.0
# 3      240.0
# 4      150.0
# Name: Value, dtype: float64

# %% [markdown]
# ### 7B).	Data Manipulation for Height Column (5 Marks).
#
# Step1: Convert Height column from Feet’ Inches unit to Inches unit by using given conversion rate 1 feet = 12 inches
# Step2: Convert the Datatype of the Height column to 'int'
#
# First 5 values of Sample Output Height column should look like this:
#
# |0 |   70|
# |-|-|
# |1|    67|
# |2 |   67|
# |3  |  71|
# |4 |   66|
# Name: Height, dtype: int32

# %%
def convert_height(value):
    feet,inch=value.split('\'')
    value= str(int(feet)* 12 + int(inch))
    return value
 
  
    
    
Fifa['Height']=Fifa['Height'].apply(convert_height)
Fifa['Height']=Fifa['Height'].astype(int)

Fifa.Height.head()
# Out:
# 0    70
# 1    67
# 2    67
# 3    71
# 4    66
# Name: Height, dtype: int32

# %% [markdown]
# ### 7C).	Data Manipulation for Weight Column (5 Marks).
#
# **Step1:** Clean Weight column by removing ‘lbs’ from each row’
#
# **Step2:** Convert the Datatype of the Weight column to 'int'
#
# **First 5 values of Sample Output Weight column should look like this:**
#
# |0  |  143|
# |--|--|
# |1  |  150|
# |2  |  159|
# |3  |  168|
# |4  |  154|
# |Name: Weight,| dtype: int32|

# %%
def convert_weight(value):
    value=value.replace('lbs','')
    return value  
    
    
Fifa['Weight']=Fifa['Weight'].apply(convert_weight)
Fifa['Weight']=Fifa['Weight'].astype(int)

Fifa.Weight.head()
# Out:
# 0    143
# 1    150
# 2    159
# 3    168
# 4    154
# Name: Weight, dtype: int32

# %%
Fifa.head()
# Out:
#     ID          Name  Age Nationality  Overall  Potential  \
# 0   16   Luis Garc¡a   37       Spain       71         71
# 1   41       Iniesta   34       Spain       86         86
# 2   80  E. Belzo?lu   37      Turkey       79         79
# 3  164      G. Pinzi   37       Italy       70         70
# 4  657    D. Vaughan   35       Wales       66         66
#
#                     Club    Value  Wage  Special  ... Skill Moves  \
# 0              KAS Eupen    750.0   ?6K     1906  ...           3
# 1            Vissel Kobe  21500.0  ?21K     2058  ...           4
# 2  Medipol Ba?ak?ehir FK   4000.0  ?23K     2047  ...           4
# 3                 Padova    240.0   ?2K     1882  ...           3
# 4           Notts County    150.0   ?4K     1781  ...           2
#
#         Work Rate  Body Type  Real Face Position Jersey Number     Joined  \
# 0  Medium/ Medium       Lean         No      RCM            10  19-Jul-14
# 1    High/ Medium     Normal        Yes       LF             8  16-Jul-18
# 2  Medium/ Medium     Stocky         No       CM             5  09-Jul-15
# 3       Low/ High     Normal         No      LCM            11  31-Aug-17
# 4    Medium/ High     Stocky         No      CDM             8  06-Jul-18
#
#   Contract Valid Until  Height Weight
# 0                 2019      70    143
# 1                 2021      67    150
# 2                 2019      67    159
# 3                 2019      71    168
# 4                 2019      66    154
#
# [5 rows x 23 columns]

# %% [markdown]
# ### 7D).   Find how many different countries players data is included in the dataset (1 Mark)

# %%
a= Fifa.describe(include='object')
a['Nationality'][1]
# Out:
# 54

# %% [markdown]
# ### 7E).	Find out highest Valued player from the dataset (1 Mark)

# %%
max_value=Fifa.Value.describe()['max']
Fifa[Fifa['Value']== max_value]['Name']
# Out:
# 41    Cristiano Ronaldo
# Name: Name, dtype: object

# %% [markdown]
# ### 7F).	Find which country's players data is maximum in the dataset and what’s is the count of it (2 Marks)

# %%
a= Fifa.describe(include='object')
print('Country:   ', a['Nationality'][2])
print('No of players:   ', a['Nationality'][3])
# Out:
# Country:    England
# No of players:    64

# %% [markdown]
# ### 7G)    Display top 10 clubs ordered by sum of all player’s current market value of that club (3 Marks)

# %%
fifa_clubwise=Fifa.groupby('Club')['Value']
fifa_clubwise_sum = fifa_clubwise.sum()
a= fifa_clubwise_sum.sort_values(ascending=False)
a[0:10]
# Out:
# Club
# Juventus                    108200.0
# Be?ikta? JK                  33500.0
# Vissel Kobe                  28000.0
# Sporting CP                  23800.0
# Manchester City              22000.0
# Villarreal CF                20700.0
# Fenerbahe SK                15850.0
# FC Bayern Mnchen            15500.0
# Borussia Mnchengladbach     15300.0
# LA Galaxy                    14595.0
# Name: Value, dtype: float64

# %% [markdown]
# ### 7H).    Count the number of players having International Reputation ratings = 4 from the clubs 'Juventus’ and ‘Be?ikta? JK’ (3 Marks)

# %%
fifa_clubwise=Fifa.groupby('Club')
RM=fifa_clubwise.get_group('Juventus')
print ('Juventus : ' ,(RM['International Reputation'] == 4).sum())
FC=fifa_clubwise.get_group('Be?ikta? JK')
print ('Be?ikta? JK : ' ,(FC['International Reputation'] == 4).sum())
# Out:
# Juventus :  1
# Be?ikta? JK :  1

# %% [markdown]
# ### 7I).	Find out the names of the youngest and oldest players from the dataset and display the distribution of age using DISTPLOT (5 Marks)

# %%
min_age=Fifa.describe()['Age']['min']
max_age=Fifa.describe()['Age']['max']
fifa_min= Fifa[Fifa['Age']==min_age]
print('Youngest Players :  ')
print(fifa_min['Name'])
print('----------------------------------------------------------------------------------------------------')
print('Oldest Players :  ')
fifa_max= Fifa[Fifa['Age']==max_age]
print(fifa_max['Name'])
# Out:
# Youngest Players :
# 208         O. ek
# 389    E. Albayrak
# Name: Name, dtype: object
# ----------------------------------------------------------------------------------------------------
# Oldest Players :
# 98         T. Warner
# 118    K. Pilkington
# Name: Name, dtype: object

# %%
import seaborn as sns
ax=sns.distplot(Fifa.Age, rug = True )
