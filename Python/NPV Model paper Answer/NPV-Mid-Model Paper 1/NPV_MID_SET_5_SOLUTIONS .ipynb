# %% [markdown]
# # Numpy and Pandas Mid exam paper

# %% [markdown]
# ###  Dataset Attributes:

# %% [markdown]
# * Patient Number
#
# * State Patient Number
#
# * Date Announced
#
# * Estimated Onset Date
#
# * Age Bracket
#
# * Gender
#
# * Detected City
#
# * Detected District
#
# * Detected State
#
# * State code
#
# * Current Status
#
# * Notes
#
# * Contracted from which Patient (Suspected)
#
# * Nationality
#
# * Type of transmission
#
# * Status Change Date
#
#
# * Backup Notes

# %% [markdown]
# ## Kindly change the below cells from markdown to code and execute it

# %% [markdown]
# import pandas as pd
#
# import csv
#
# with open("data_set.csv","r")as file:
#
#     reader=csv.reader(file)
#
# df=pd.read_csv("data_set.csv")
#
# df.head()

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import math

# %%
Data = pd.read_csv("raw_data_Covid_India.csv")

# %% [markdown]
# -------
# # Section A: 8 Marks
# -----------

# %% [markdown]
# ### 1. What are the different types Of data structures in Pandas? (8 Marks)

# %% [markdown]
# Pandas has mainly two data structures
#
# * Series
# * DataFrame
#
# Both of which are built on top of NumPy. Series is one dimensional homogenous array. And Pandas DataFrame is two-dimensional size-mutable, potentially heterogeneous tabular data structure with labeled axes.
#
# 1. Series:
#
# Series is a one-dimensional object similar to an array, list, or column in a table. It will assign a labeled index to each item in the Series.
#
# 2. Data Frame:
#
# A Data frame is a two-dimensional data structure, i.e., data is aligned in a tabular fashion in rows and columns. Pandas DataFrame consists of three principal components, the data, rows, and columns.

# %% [markdown]
# -------
# # Section B: 17 Marks
# -----------

# %% [markdown]
# ### 2. Find the number of recovered and deceased cases in Kerala? (6 Marks)

# %%
df_cured_Kerala = Data[(Data["Current Status"]=="Recovered") & (Data["Detected State"]== "Kerala")]
df_cured_Kerala["Current Status"].value_counts()
# Out:
# Recovered    3
# Name: Current Status, dtype: int64

# %%
df_Deceased_Kerala = Data[(Data["Current Status"]=="Deceased") & (Data["Detected State"]== "Kerala")]
df_Deceased_Kerala["Current Status"].value_counts()
# Out:
# Series([], Name: Current Status, dtype: int64)

# %% [markdown]
# ###  3. Find the number of Female and Male Recovered from Kerala? (5 Marks)

# %%
df_cured_Kerala = Data[(Data["Current Status"]=="Recovered") & (Data["Detected State"]== "Kerala")]
Female_cured_kerala = df_cured_Kerala[(df_cured_Kerala["Gender"] == "F")]
Female_cured_kerala["Gender"].value_counts()
# Out:
# F    1
# Name: Gender, dtype: int64

# %%
male_cured_kerala = df_cured_Kerala[(df_cured_Kerala["Gender"] == "M")]
male_cured_kerala["Gender"].value_counts()
# Out:
# Series([], Name: Gender, dtype: int64)

# %% [markdown]
# ### 4. What is the cause behind the people of Gurugram city to get corona? (6 Marks)

# %%
Data[Data["Detected City"] == "Gurugram"]
# Out:
#    Patient Number State Patient Number Date Announced  Estimated Onset Date  \
# 6               7                  NaN     04-03-2020                   NaN
# 7               8                  NaN     04-03-2020                   NaN
#
#    Age Bracket Gender Detected City Detected District Detected State  \
# 6         55.0    NaN      Gurugram         Italians*        Haryana
# 7         55.0    NaN      Gurugram         Italians*        Haryana
#
#   State code Current Status                 Notes  \
# 6         HR      Recovered  Travelled from Italy
# 7         HR      Recovered  Travelled from Italy
#
#   Contracted from which Patient (Suspected) Nationality Type of transmission  \
# 6                                        P6       Italy             Imported
# 7                                        P6       Italy             Imported
#
#   Status Change Date     Backup Notes
# 6         29-03-2020  Italian tourist
# 7         29-03-2020  Italian tourist

# %%
df_Haryana = Data[Data["Detected City"]== "Gurugram"]
df_Haryana["Notes"].value_counts()
# Out:
# Travelled from Italy    2
# Name: Notes, dtype: int64

# %% [markdown]
#  * Most of the travell from Italy

# %% [markdown]
# -------
# # Section C: 25 Marks
# -----------

# %% [markdown]
# ### 5a. How many people Travelled from Wuhan in Kerala. (5 Marks)
#
# ### 5b. How many people  recovered in Kerala ? (3 Marks)

# %%
df_cured_Kerala = Data[(Data["Notes"]=="Travelled from Wuhan") & (Data["Detected State"]== "Kerala")]
df_cured_Kerala["Notes"].value_counts()
# Out:
# Travelled from Wuhan    3
# Name: Notes, dtype: int64

# %% [markdown]
# * 3 people  Travelled from Wuhan in Kerala

# %%
df_cured_Kerala = df_cured_Kerala[(df_cured_Kerala["Current Status"]=="Recovered")]
df_cured_Kerala["Current Status"].value_counts()
# Out:
# Recovered    3
# Name: Current Status, dtype: int64

# %% [markdown]
# * 3 people  recovered

# %% [markdown]
# ### 6. Find the percentage of male and female got COVID-19 using the subplots with the combination of (pie & count) graphs at the same time (6 Marks)

# %%
f,ax=plt.subplots(1,2,figsize=(12,8))
Data['Gender'].value_counts().plot.pie(explode=[0,0.1],autopct='%1.1f%%',ax=ax[0],shadow=True)
ax[0].set_title('Gender')
ax[0].set_ylabel('')
sns.countplot('Gender',data=Data,ax=ax[1])
ax[1].set_title('Gender')
plt.show()

# %% [markdown]
# ### 7. Display the count plot to show the number of people got affected based on states. (5 Marks)

# %%
plt.figure(figsize=(7,7))
sns.countplot(y=Data['Detected State'],).set_title('Regions affected Overall')
# Out:
# Text(0.5, 1.0, 'Regions affected Overall')

# %% [markdown]
# ### 8 .  Display the count plot for the Recovered patients in the Detected State column. (6 Marks)

# %%
plt.figure(figsize=(8,8))
sns.countplot(y=Data['Detected State'].loc[(Data['Current Status']=="Recovered")],).set_title('Recovered Status in States')
# Out:
# Text(0.5, 1.0, 'Recovered Status in States')
